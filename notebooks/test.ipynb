# %% [markdown]
# # Secção 1

# %%
print("Hello, World!")

# %% [markdown]
# # Secção 2

# %% [markdown]
# Esta secção realiza o processamento de dados.

# %% [markdown]
# ## Secção 2.1

# %%
a = 5
b = 10
print("Sum:", a + b)
