# %% [markdown]
# # CONFIGURAÇÕES INICIAIS
#
# »» Recursos de interesse:
#
# - Markdown: https://www.markdownguide.org/

# %% [markdown]
# ## Diretorias

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\pauloricardolb\\OneDrive - Universidade de Aveiro\\TRABALHO_AULAS\\AL20232024\\ICD\\projICD\\notebooks'

# %% [markdown]
# ## Ativar os módulos de interesse

# %%
import requests
import json

import pickle

import math 
import pandas as pd

# %% [markdown]
# ## Funções auxiliares

# %%
# A função "jprint()" tem como objetivo "imprimir" o json (formato de resposta escolhido / solicitado à API) 
# O formato ".json" é uma linguagem utilizada para representação de dados num formato do tipo "chave-valor" - numa estrutura de dados similar a um "dicionário", 
# disponibilizada na linguagem Python. 
# Os dados, tal como numa base de dados usual, podem ter uma estrutura relacional; é usual que estas relações possam ser representadas num formato
# hierárquico. O formato json é assim compatível com esta representação relacional hierárquica, sendo a navegação entre os diferentes níveis definida pelas chaves, 
# que correspondem aos nós da representação hierárquica em rede dos referidos dados codificados no formato json
# Esta função permite representar a estrutura hierárquica do json, através da "impressão" em formato textual, utilizando tabulações por forma a alinhar as chaves que se encontram
# em cada nível hierárquico

def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=6)
    print(text)

# %% [markdown]
# ## Configuração Chave API

# %%
from decouple import config

MY_SCOPUS_API_KEY = config('MY_SCOPUS_API_KEY')

print('my scopus api key is :', MY_SCOPUS_API_KEY)
# Out:
# my scopus api key is : d0178a452f02df51b64ba796b0b9b4da

# %%
from decouple import Config, RepositoryEnv

DOTENV_FILE = '../.env'
env_config = Config(RepositoryEnv(DOTENV_FILE))

# use the Config().get() method as you normally would since 
# decouple.config uses that internally. 
# i.e. config('SECRET_KEY') = env_config.get('SECRET_KEY')
MY_SCOPUS_API_KEY = env_config.get('MY_SCOPUS_API_KEY')

print('my scopus api key is :', MY_SCOPUS_API_KEY)
# Out:
# my scopus api key is : d0178a452f02df51b64ba796b0b9b4da

# %% [markdown]
# # RECOLHA DE DADOS - Parte 1
# Pesquisa e recolha de resultados com a API Scoupus API

# %% [markdown]
# ## Análise exploratória dos resultados de pesquisa

# %% [markdown]
# ### Exploratório: 1. Pesquisa API

# %%
# IMPORTANTE: https://dev.elsevier.com/sc_search_tips.html

user_query = "data mining housing automated valuation model"

response = requests.get("https://api.elsevier.com/content/search/scopus",
                    headers={'Accept':'application/json',
                             'X-ELS-APIKey': MY_SCOPUS_API_KEY},
                         
                    params={    'query' : user_query,
                                #'start' : "1"
                        }

                        )

print(response.url)
# Out:
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model

# %% [markdown]
# ### Exploratório: 2. Analisar resultados / resposta API

# %%
print(response.status_code)
# Out:
# 200

# %%
# A simples invocação da resposta da API (em formato json) imprime o contéudo obtido com a respetiva syntaxe json
# No entanto, como facilmente se depreende desta forma é dificil discernir a estrutura hierárquica dos dados e, desta forma, extrair os diferentes dados em cada nível
# por forma a transformar os dados numa estrutura de dados mais amigável (por exemplo, um data.frame da livraria "pandas", que nos é uma estrutura de dados mais familiar
# para manipulação)
results = response.json()
results
# Out:
# {'search-results': {'opensearch:totalResults': '335',
#   'opensearch:startIndex': '0',
#   'opensearch:itemsPerPage': '25',
#   'opensearch:Query': {'@role': 'request',
#    '@searchTerms': 'data mining housing automated valuation model',
#    '@startPage': '0'},
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=0&count=25&query=data+mining+housing+automated+valuation+model',
#     '@type': 'application/json'},
#    {'@_fa': 'true',
#     '@ref': 'first',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=0&count=25&query=data+mining+housing+automated+valuation+model',
#     '@type': 'application/json'},
#    {'@_fa': 'true',
#     '@ref': 'next',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=25&count=25&query=data+mining+housing+automated+valuation+model',
#     '@type': 'application/json'},
#    {'@_fa': 'true',
#     '@ref': 'last',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=310&count=25&query=data+mining+housing+automated+valuation+model',
#     '@type': 'application/json'}],
#   'entry': [{'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85175657733'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85175657733?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85175657733&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85175657733&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0952197623015312'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85175657733',
#     'dc:identifier': 'SCOPUS_ID:85175657733',
#     'eid': '2-s2.0-85175657733',
#     'dc:title': 'Selecting the ideal sustainable green strategy for logistics companies using a T-spherical fuzzy-based methodology',
#     'dc:creator': 'Aytekin A.',
#     'prism:publicationName': 'Engineering Applications of Artificial Intelligence',
#     'prism:issn': '09521976',
#     'prism:volume': '127',
#     'prism:pageRange': None,
#     'prism:coverDate': '2024-01-01',
#     'prism:coverDisplayDate': 'January 2024',
#     'prism:doi': '10.1016/j.engappai.2023.107347',
#     'pii': 'S0952197623015312',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Artvin Coruh University, Turkey',
#       'affiliation-city': 'Artvin',
#       'affiliation-country': 'Turkey'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '107347',
#     'source-id': '24182',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85169292928'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85169292928?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85169292928&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85169292928&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0957417423015610'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85169292928',
#     'dc:identifier': 'SCOPUS_ID:85169292928',
#     'eid': '2-s2.0-85169292928',
#     'dc:title': 'Improving hedonic housing price models by integrating optimal accessibility indices into regression and random forest analyses',
#     'dc:creator': 'Rey-Blanco D.',
#     'prism:publicationName': 'Expert Systems with Applications',
#     'prism:issn': '09574174',
#     'prism:volume': '235',
#     'prism:pageRange': None,
#     'prism:coverDate': '2024-01-01',
#     'prism:coverDisplayDate': 'January 2024',
#     'prism:doi': '10.1016/j.eswa.2023.121059',
#     'pii': 'S0957417423015610',
#     'citedby-count': '1',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Universidad Nacional de Educacion a Distancia',
#       'affiliation-city': 'Madrid',
#       'affiliation-country': 'Spain'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '121059',
#     'source-id': '24201',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherhybridgold'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Hybrid Gold'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85176104737'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85176104737?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85176104737&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85176104737&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85176104737',
#     'dc:identifier': 'SCOPUS_ID:85176104737',
#     'eid': '2-s2.0-85176104737',
#     'dc:title': 'Remnants of a Young Monogenetic Volcanic Field and the Fragile Balance of Anthropogenic Interaction',
#     'dc:creator': 'Foote A.',
#     'prism:publicationName': 'Geoheritage',
#     'prism:issn': '18672477',
#     'prism:eIssn': '18672485',
#     'prism:volume': '15',
#     'prism:issueIdentifier': '4',
#     'prism:pageRange': None,
#     'prism:coverDate': '2023-12-01',
#     'prism:coverDisplayDate': 'December 2023',
#     'prism:doi': '10.1007/s12371-023-00897-8',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Macquarie University',
#       'affiliation-city': 'Sydney',
#       'affiliation-country': 'Australia'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '131',
#     'source-id': '19600157344',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherhybridgold'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Hybrid Gold'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85173445512'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85173445512?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85173445512&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85173445512&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85173445512',
#     'dc:identifier': 'SCOPUS_ID:85173445512',
#     'eid': '2-s2.0-85173445512',
#     'dc:title': 'Tech for good: Imagine solving the world? Greatest challenges',
#     'dc:creator': 'Hoek M.',
#     'prism:publicationName': 'Tech For Good: Imagine Solving the World? Greatest Challenges',
#     'prism:isbn': [{'@_fa': 'true', '$': '9781003392064'},
#      {'@_fa': 'true', '$': '9781032490731'}],
#     'prism:pageRange': '1-364',
#     'prism:coverDate': '2023-11-29',
#     'prism:coverDisplayDate': '29 November 2023',
#     'prism:doi': '10.4324/9781003392064',
#     'citedby-count': '0',
#     'prism:aggregationType': 'Book',
#     'subtype': 'bk',
#     'subtypeDescription': 'Book',
#     'source-id': '21101181802',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85171132950'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85171132950?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85171132950&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85171132950&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S2352710223018958'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85171132950',
#     'dc:identifier': 'SCOPUS_ID:85171132950',
#     'eid': '2-s2.0-85171132950',
#     'dc:title': 'LOD2 for energy simulation (LOD2ES) for CityGML: A novel level of details model for IFC-based building features extraction and energy simulation',
#     'dc:creator': 'Xu H.',
#     'prism:publicationName': 'Journal of Building Engineering',
#     'prism:eIssn': '23527102',
#     'prism:volume': '78',
#     'prism:pageRange': None,
#     'prism:coverDate': '2023-11-01',
#     'prism:coverDisplayDate': '1 November 2023',
#     'prism:doi': '10.1016/j.jobe.2023.107715',
#     'pii': 'S2352710223018958',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'City University of Hong Kong',
#       'affiliation-city': 'Hong Kong',
#       'affiliation-country': 'Hong Kong'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '107715',
#     'source-id': '21100389518',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85177610748'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85177610748?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85177610748&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85177610748&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85177610748',
#     'dc:identifier': 'SCOPUS_ID:85177610748',
#     'eid': '2-s2.0-85177610748',
#     'dc:title': 'Management, technology, and economic growth in smart and sustainable cities',
#     'dc:creator': 'Ruiz-Vanoye J.A.',
#     'prism:publicationName': 'Management, Technology, and Economic Growth in Smart and Sustainable Cities',
#     'prism:isbn': [{'@_fa': 'true', '$': '9798369303757'},
#      {'@_fa': 'true', '$': '9798369303733'}],
#     'prism:pageRange': '1-341',
#     'prism:coverDate': '2023-10-24',
#     'prism:coverDisplayDate': '24 October 2023',
#     'prism:doi': '10.4018/9798369303733',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Universidad Politécnica de Pachuca',
#       'affiliation-city': 'Pachuca',
#       'affiliation-country': 'Mexico'}],
#     'prism:aggregationType': 'Book',
#     'subtype': 'bk',
#     'subtypeDescription': 'Book',
#     'source-id': '21101187906',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85175073728'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85175073728?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85175073728&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85175073728&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85175073728',
#     'dc:identifier': 'SCOPUS_ID:85175073728',
#     'eid': '2-s2.0-85175073728',
#     'dc:title': 'Investigation of Real Estate Tax Leakage Loss Rates with ANNs',
#     'dc:creator': 'Yılmaz M.',
#     'prism:publicationName': 'Buildings',
#     'prism:eIssn': '20755309',
#     'prism:volume': '13',
#     'prism:issueIdentifier': '10',
#     'prism:pageRange': None,
#     'prism:coverDate': '2023-10-01',
#     'prism:coverDisplayDate': 'October 2023',
#     'prism:doi': '10.3390/buildings13102464',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Kayseri University',
#       'affiliation-city': 'Kayseri',
#       'affiliation-country': 'Turkey'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '2464',
#     'source-id': '26980',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85173965875'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85173965875?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85173965875&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85173965875&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85173965875',
#     'dc:identifier': 'SCOPUS_ID:85173965875',
#     'eid': '2-s2.0-85173965875',
#     'dc:title': 'Hydrogeophysical Survey for Assessment of Groundwater Budget and Aquifer Protection in Hilly Terrain',
#     'dc:creator': 'Singh S.',
#     'prism:publicationName': 'Journal of Mining and Environment',
#     'prism:issn': '22518592',
#     'prism:eIssn': '22518606',
#     'prism:volume': '14',
#     'prism:issueIdentifier': '4',
#     'prism:pageRange': '1061-1079',
#     'prism:coverDate': '2023-10-01',
#     'prism:coverDisplayDate': 'October 2023',
#     'prism:doi': '10.22044/jme.2023.12816.2329',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'National Institute of Technology Hamirpur',
#       'affiliation-city': 'Hamirpur',
#       'affiliation-country': 'India'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'source-id': '21101073709',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85139904399'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85139904399?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85139904399&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85139904399&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85139904399',
#     'dc:identifier': 'SCOPUS_ID:85139904399',
#     'eid': '2-s2.0-85139904399',
#     'dc:title': 'A Hybrid Approach for Mass Valuation of Residential Properties through Geographic Information Systems and Machine Learning Integration',
#     'dc:creator': 'Mete M.O.',
#     'prism:publicationName': 'Geographical Analysis',
#     'prism:issn': '00167363',
#     'prism:eIssn': '15384632',
#     'prism:volume': '55',
#     'prism:issueIdentifier': '4',
#     'prism:pageRange': '535-559',
#     'prism:coverDate': '2023-10-01',
#     'prism:coverDisplayDate': 'October 2023',
#     'prism:doi': '10.1111/gean.12350',
#     'citedby-count': '1',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'İstanbul Teknik Üniversitesi',
#       'affiliation-city': 'Istanbul',
#       'affiliation-country': 'Turkey'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'source-id': '28671',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85175499418'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85175499418?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85175499418&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85175499418&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85175499418',
#     'dc:identifier': 'SCOPUS_ID:85175499418',
#     'eid': '2-s2.0-85175499418',
#     'dc:title': 'Energy policy design in the eastern mediterranean basin: A roadmap to energy efficiency',
#     'dc:creator': 'Ozarisoy B.',
#     'prism:publicationName': 'Energy Policy Design in the Eastern Mediterranean Basin: A Roadmap to Energy Efficiency',
#     'prism:isbn': [{'@_fa': 'true', '$': '9781000921823'},
#      {'@_fa': 'true', '$': '9781032493053'}],
#     'prism:pageRange': '1-524',
#     'prism:coverDate': '2023-09-28',
#     'prism:coverDisplayDate': '28 September 2023',
#     'prism:doi': '10.4324/9781003393092',
#     'citedby-count': '0',
#     'prism:aggregationType': 'Book',
#     'subtype': 'bk',
#     'subtypeDescription': 'Book',
#     'source-id': '21101185234',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85175667493'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85175667493?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85175667493&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85175667493&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85175667493',
#     'dc:identifier': 'SCOPUS_ID:85175667493',
#     'eid': '2-s2.0-85175667493',
#     'dc:title': 'Transformational Leadership Styles for Global Leaders: Management and Communication Strategies',
#     'dc:creator': 'Roache D.A.M.',
#     'prism:publicationName': 'Transformational Leadership Styles for Global Leaders: Management and Communication Strategies',
#     'prism:isbn': [{'@_fa': 'true', '$': '9798369313817'},
#      {'@_fa': 'true', '$': '9798369313800'}],
#     'prism:pageRange': '1-545',
#     'prism:coverDate': '2023-09-26',
#     'prism:coverDisplayDate': '26 September 2023',
#     'prism:doi': '10.4018/979-8-3693-1380-0',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'University Canada West',
#       'affiliation-city': 'Vancouver',
#       'affiliation-country': 'Canada'}],
#     'prism:aggregationType': 'Book',
#     'subtype': 'bk',
#     'subtypeDescription': 'Book',
#     'source-id': '21101185309',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85168374032'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85168374032?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85168374032&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85168374032&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S019739752300156X'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85168374032',
#     'dc:identifier': 'SCOPUS_ID:85168374032',
#     'eid': '2-s2.0-85168374032',
#     'dc:title': 'Understanding the land use intensity of residential buildings in Brazil: An ensemble machine learning approach',
#     'dc:creator': 'Belmiro C.',
#     'prism:publicationName': 'Habitat International',
#     'prism:issn': '01973975',
#     'prism:volume': '139',
#     'prism:pageRange': None,
#     'prism:coverDate': '2023-09-01',
#     'prism:coverDisplayDate': 'September 2023',
#     'prism:doi': '10.1016/j.habitatint.2023.102896',
#     'pii': 'S019739752300156X',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Federal University of Penambuco',
#       'affiliation-city': 'Recife',
#       'affiliation-country': 'Brazil'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '102896',
#     'source-id': '13760',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfree2read'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Bronze'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85163172049'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85163172049?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163172049&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85163172049&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S2772662223001078'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85163172049',
#     'dc:identifier': 'SCOPUS_ID:85163172049',
#     'eid': '2-s2.0-85163172049',
#     'dc:title': 'A Gaussian process regression machine learning model for forecasting retail property prices with Bayesian optimizations and cross-validation',
#     'dc:creator': 'Xu X.',
#     'prism:publicationName': 'Decision Analytics Journal',
#     'prism:eIssn': '27726622',
#     'prism:volume': '8',
#     'prism:pageRange': None,
#     'prism:coverDate': '2023-09-01',
#     'prism:coverDisplayDate': 'September 2023',
#     'prism:doi': '10.1016/j.dajour.2023.100267',
#     'pii': 'S2772662223001078',
#     'citedby-count': '5',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'NC State University',
#       'affiliation-city': 'Raleigh',
#       'affiliation-country': 'United States'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '100267',
#     'source-id': '21101098756',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85132747566'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85132747566?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85132747566&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85132747566&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85132747566',
#     'dc:identifier': 'SCOPUS_ID:85132747566',
#     'eid': '2-s2.0-85132747566',
#     'dc:title': 'Interpretable machine learning for real estate market analysis',
#     'dc:creator': 'Lorenz F.',
#     'prism:publicationName': 'Real Estate Economics',
#     'prism:issn': '10808620',
#     'prism:eIssn': '15406229',
#     'prism:volume': '51',
#     'prism:issueIdentifier': '5',
#     'prism:pageRange': '1178-1208',
#     'prism:coverDate': '2023-09-01',
#     'prism:coverDisplayDate': 'September 2023',
#     'prism:doi': '10.1111/1540-6229.12397',
#     'citedby-count': '9',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Universität Regensburg',
#       'affiliation-city': 'Regensburg',
#       'affiliation-country': 'Germany'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'source-id': '24900',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherhybridgold'},
#       {'$': 'repository'},
#       {'$': 'repositoryvor'},
#       {'$': 'repositoryam'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Hybrid Gold'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85159631828'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85159631828?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159631828&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85159631828&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S235271022300904X'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85159631828',
#     'dc:identifier': 'SCOPUS_ID:85159631828',
#     'eid': '2-s2.0-85159631828',
#     'dc:title': 'A systematic literature review on modern methods of construction in building: An integrated approach using machine learning',
#     'dc:creator': 'Sánchez-Garrido A.J.',
#     'prism:publicationName': 'Journal of Building Engineering',
#     'prism:eIssn': '23527102',
#     'prism:volume': '73',
#     'prism:pageRange': None,
#     'prism:coverDate': '2023-08-15',
#     'prism:coverDisplayDate': '15 August 2023',
#     'prism:doi': '10.1016/j.jobe.2023.106725',
#     'pii': 'S235271022300904X',
#     'citedby-count': '4',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Universitat Politècnica de València',
#       'affiliation-city': 'Valencia',
#       'affiliation-country': 'Spain'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 're',
#     'subtypeDescription': 'Review',
#     'article-number': '106725',
#     'source-id': '21100389518',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherhybridgold'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Hybrid Gold'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85128646592'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85128646592?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85128646592&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85128646592&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85128646592',
#     'dc:identifier': 'SCOPUS_ID:85128646592',
#     'eid': '2-s2.0-85128646592',
#     'dc:title': 'Longitudinal modelling of housing prices with machine learning and temporal regression',
#     'dc:creator': 'Zhang Y.',
#     'prism:publicationName': 'International Journal of Housing Markets and Analysis',
#     'prism:issn': '17538270',
#     'prism:eIssn': '17538289',
#     'prism:volume': '16',
#     'prism:issueIdentifier': '4',
#     'prism:pageRange': '693-715',
#     'prism:coverDate': '2023-08-14',
#     'prism:coverDisplayDate': '14 August 2023',
#     'prism:doi': '10.1108/IJHMA-02-2022-0033',
#     'citedby-count': '1',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'University of Toronto',
#       'affiliation-city': 'Toronto',
#       'affiliation-country': 'Canada'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'source-id': '21100202720',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85167877066'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85167877066?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167877066&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85167877066&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85167877066',
#     'dc:identifier': 'SCOPUS_ID:85167877066',
#     'eid': '2-s2.0-85167877066',
#     'dc:title': 'An Analysis of Residual Financial Contagion in Romania’s Banking Market for Mortgage Loans',
#     'dc:creator': 'Ionescu Ș.',
#     'prism:publicationName': 'Sustainability (Switzerland)',
#     'prism:eIssn': '20711050',
#     'prism:volume': '15',
#     'prism:issueIdentifier': '15',
#     'prism:pageRange': None,
#     'prism:coverDate': '2023-08-01',
#     'prism:coverDisplayDate': 'August 2023',
#     'prism:doi': '10.3390/su151512037',
#     'citedby-count': '1',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Bucharest University of Economic Studies',
#       'affiliation-city': 'Bucharest',
#       'affiliation-country': 'Romania'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '12037',
#     'source-id': '21100240100',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85152096403'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85152096403?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152096403&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85152096403&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85152096403',
#     'dc:identifier': 'SCOPUS_ID:85152096403',
#     'eid': '2-s2.0-85152096403',
#     'dc:title': 'The role of neural network for estimating real estate prices value in post COVID-19: a case of the middle east market',
#     'dc:creator': 'Khrais L.T.',
#     'prism:publicationName': 'International Journal of Electrical and Computer Engineering',
#     'prism:issn': '20888708',
#     'prism:volume': '13',
#     'prism:issueIdentifier': '4',
#     'prism:pageRange': '4516-4525',
#     'prism:coverDate': '2023-08-01',
#     'prism:coverDisplayDate': 'August 2023',
#     'prism:doi': '10.11591/ijece.v13i4.pp4516-4525',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Imam Abdulrahman Bin Faisal University',
#       'affiliation-city': 'Dammam',
#       'affiliation-country': 'Saudi Arabia'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'source-id': '21100373959',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherfullgold'},
#       {'$': 'repository'},
#       {'$': 'repositoryvor'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Gold'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85166192427'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85166192427?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166192427&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85166192427&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85166192427',
#     'dc:identifier': 'SCOPUS_ID:85166192427',
#     'eid': '2-s2.0-85166192427',
#     'dc:title': 'Interpreting Housing Prices with a MultidisciplinaryApproach Based on Nature-Inspired Algorithms and Quantum Computing',
#     'dc:creator': 'De Paola P.',
#     'prism:publicationName': 'Buildings',
#     'prism:eIssn': '20755309',
#     'prism:volume': '13',
#     'prism:issueIdentifier': '7',
#     'prism:pageRange': None,
#     'prism:coverDate': '2023-07-01',
#     'prism:coverDisplayDate': 'July 2023',
#     'prism:doi': '10.3390/buildings13071603',
#     'citedby-count': '1',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Università degli Studi di Napoli Federico II',
#       'affiliation-city': 'Naples',
#       'affiliation-country': 'Italy'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '1603',
#     'source-id': '26980',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85152396843'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85152396843?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152396843&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85152396843&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S2214629623001470'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85152396843',
#     'dc:identifier': 'SCOPUS_ID:85152396843',
#     'eid': '2-s2.0-85152396843',
#     'dc:title': 'Alleviation of energy poverty through transitions to low-carbon energy infrastructure',
#     'dc:creator': 'Lippert I.',
#     'prism:publicationName': 'Energy Research and Social Science',
#     'prism:issn': '22146296',
#     'prism:volume': '100',
#     'prism:pageRange': None,
#     'prism:coverDate': '2023-06-01',
#     'prism:coverDisplayDate': 'June 2023',
#     'prism:doi': '10.1016/j.erss.2023.103087',
#     'pii': 'S2214629623001470',
#     'citedby-count': '4',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Brandenburgische Technische Universität Cottbus',
#       'affiliation-city': 'Cottbus',
#       'affiliation-country': 'Germany'},
#      {'@_fa': 'true',
#       'affilname': 'IT-Universitetet i København',
#       'affiliation-city': 'Copenhagen',
#       'affiliation-country': 'Denmark'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 're',
#     'subtypeDescription': 'Review',
#     'article-number': '103087',
#     'source-id': '21100325067',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherhybridgold'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Hybrid Gold'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85143420111'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85143420111?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85143420111&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85143420111&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85143420111',
#     'dc:identifier': 'SCOPUS_ID:85143420111',
#     'eid': '2-s2.0-85143420111',
#     'dc:title': 'A supervised machine learning model for imputing missing boarding stops in smart card data',
#     'dc:creator': 'Shalit N.',
#     'prism:publicationName': 'Public Transport',
#     'prism:issn': '1866749X',
#     'prism:eIssn': '16137159',
#     'prism:volume': '15',
#     'prism:issueIdentifier': '2',
#     'prism:pageRange': '287-319',
#     'prism:coverDate': '2023-06-01',
#     'prism:coverDisplayDate': 'June 2023',
#     'prism:doi': '10.1007/s12469-022-00309-0',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Ben-Gurion University of the Negev',
#       'affiliation-city': 'Beer Sheva',
#       'affiliation-country': 'Israel'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'source-id': '19600161828',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherfree2read'},
#       {'$': 'repository'},
#       {'$': 'repositoryam'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Bronze'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85160323109'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85160323109?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85160323109&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85160323109&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85160323109',
#     'dc:identifier': 'SCOPUS_ID:85160323109',
#     'eid': '2-s2.0-85160323109',
#     'dc:title': 'A Survey of Methods and Input Data Types for House Price Prediction',
#     'dc:creator': 'Geerts M.',
#     'prism:publicationName': 'ISPRS International Journal of Geo-Information',
#     'prism:eIssn': '22209964',
#     'prism:volume': '12',
#     'prism:issueIdentifier': '5',
#     'prism:pageRange': None,
#     'prism:coverDate': '2023-05-01',
#     'prism:coverDisplayDate': 'May 2023',
#     'prism:doi': '10.3390/ijgi12050200',
#     'citedby-count': '2',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'KU Leuven',
#       'affiliation-city': '3000 Leuven',
#       'affiliation-country': 'Belgium'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 're',
#     'subtypeDescription': 'Review',
#     'article-number': '200',
#     'source-id': '21100427639',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherfullgold'},
#       {'$': 'repository'},
#       {'$': 'repositoryvor'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Gold'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85159354367'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85159354367?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159354367&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85159354367&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85159354367',
#     'dc:identifier': 'SCOPUS_ID:85159354367',
#     'eid': '2-s2.0-85159354367',
#     'dc:title': 'Intelligent Multi-Criteria Decision Support for Renovation Solutions for a Building Based on Emotion Recognition by Applying the COPRAS Method and BIM Integration',
#     'dc:creator': 'Velykorusova A.',
#     'prism:publicationName': 'Applied Sciences (Switzerland)',
#     'prism:eIssn': '20763417',
#     'prism:volume': '13',
#     'prism:issueIdentifier': '9',
#     'prism:pageRange': None,
#     'prism:coverDate': '2023-05-01',
#     'prism:coverDisplayDate': 'May 2023',
#     'prism:doi': '10.3390/app13095453',
#     'citedby-count': '1',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Vilniaus Gedimino Technikos Universitetas',
#       'affiliation-city': 'Vilnius',
#       'affiliation-country': 'Lithuania'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '5453',
#     'source-id': '21100829268',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherfullgold'},
#       {'$': 'repository'},
#       {'$': 'repositoryvor'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Gold'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85143233595'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85143233595?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85143233595&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85143233595&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85143233595',
#     'dc:identifier': 'SCOPUS_ID:85143233595',
#     'eid': '2-s2.0-85143233595',
#     'dc:title': 'Testing machine learning systems in real estate',
#     'dc:creator': 'Wan W.X.',
#     'prism:publicationName': 'Real Estate Economics',
#     'prism:issn': '10808620',
#     'prism:eIssn': '15406229',
#     'prism:volume': '51',
#     'prism:issueIdentifier': '3',
#     'prism:pageRange': '754-778',
#     'prism:coverDate': '2023-05-01',
#     'prism:coverDisplayDate': 'May 2023',
#     'prism:doi': '10.1111/1540-6229.12416',
#     'citedby-count': '1',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Monash University',
#       'affiliation-city': 'Melbourne',
#       'affiliation-country': 'Australia'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'source-id': '24900',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfree2read'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Bronze'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85163458236'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85163458236?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163458236&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85163458236&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85163458236',
#     'dc:identifier': 'SCOPUS_ID:85163458236',
#     'eid': '2-s2.0-85163458236',
#     'dc:title': 'Emerging trends, techniques, and applications in geospatial data science',
#     'dc:creator': 'Gaur L.',
#     'prism:publicationName': 'Emerging Trends, Techniques, and Applications in Geospatial Data Science',
#     'prism:isbn': [{'@_fa': 'true', '$': '9781668473214'},
#      {'@_fa': 'true', '$': '9781668473191'}],
#     'prism:pageRange': '1-309',
#     'prism:coverDate': '2023-04-24',
#     'prism:coverDisplayDate': '24 April 2023',
#     'prism:doi': '10.4018/978-1-6684-7319-1',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': "Taylor's University Malaysia",
#       'affiliation-city': 'Subang Jaya',
#       'affiliation-country': 'Malaysia'},
#      {'@_fa': 'true',
#       'affilname': 'University of the South Pacific',
#       'affiliation-city': 'Suva',
#       'affiliation-country': 'Fiji'}],
#     'prism:aggregationType': 'Book',
#     'subtype': 'bk',
#     'subtypeDescription': 'Book',
#     'source-id': '21101161806',
#     'openaccess': '0',
#     'openaccessFlag': False}]}}

# %%
# Podemos assim invocar a função "jprint" que definimos inicialmente para obtermos uma visualização mais amigável da estrutura de dados codificada no json
# Esta visualização permite-nos ainda identificar a "localização" (na hierarquia) dos dados de interesse e, portanto, as respetivas chaves (que nos permitem
# aceder a esses mesmos dados)
jprint(response.json())
# Out:
# {
#       "search-results": {
#             "entry": [
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Artvin",
#                                     "affiliation-country": "Turkey",
#                                     "affilname": "Artvin Coruh University, Turkey"
#                               }
#                         ],
#                         "article-number": "107347",
#                         "citedby-count": "0",
#                         "dc:creator": "Aytekin A.",
#                         "dc:identifier": "SCOPUS_ID:85175657733",
#                         "dc:title": "Selecting the ideal sustainable green strategy for logistics companies using a T-spherical fuzzy-based methodology",
#                         "eid": "2-s2.0-85175657733",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85175657733",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85175657733?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85175657733&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85175657733&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S0952197623015312",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "pii": "S0952197623015312",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2024-01-01",
#                         "prism:coverDisplayDate": "January 2024",
#                         "prism:doi": "10.1016/j.engappai.2023.107347",
#                         "prism:issn": "09521976",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Engineering Applications of Artificial Intelligence",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85175657733",
#                         "prism:volume": "127",
#                         "source-id": "24182",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Madrid",
#                                     "affiliation-country": "Spain",
#                                     "affilname": "Universidad Nacional de Educacion a Distancia"
#                               }
#                         ],
#                         "article-number": "121059",
#                         "citedby-count": "1",
#                         "dc:creator": "Rey-Blanco D.",
#                         "dc:identifier": "SCOPUS_ID:85169292928",
#                         "dc:title": "Improving hedonic housing price models by integrating optimal accessibility indices into regression and random forest analyses",
#                         "eid": "2-s2.0-85169292928",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherhybridgold"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Hybrid Gold"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85169292928",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85169292928?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85169292928&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85169292928&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S0957417423015610",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "pii": "S0957417423015610",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2024-01-01",
#                         "prism:coverDisplayDate": "January 2024",
#                         "prism:doi": "10.1016/j.eswa.2023.121059",
#                         "prism:issn": "09574174",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Expert Systems with Applications",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85169292928",
#                         "prism:volume": "235",
#                         "source-id": "24201",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Sydney",
#                                     "affiliation-country": "Australia",
#                                     "affilname": "Macquarie University"
#                               }
#                         ],
#                         "article-number": "131",
#                         "citedby-count": "0",
#                         "dc:creator": "Foote A.",
#                         "dc:identifier": "SCOPUS_ID:85176104737",
#                         "dc:title": "Remnants of a Young Monogenetic Volcanic Field and the Fragile Balance of Anthropogenic Interaction",
#                         "eid": "2-s2.0-85176104737",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherhybridgold"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Hybrid Gold"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85176104737",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85176104737?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85176104737&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85176104737&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-12-01",
#                         "prism:coverDisplayDate": "December 2023",
#                         "prism:doi": "10.1007/s12371-023-00897-8",
#                         "prism:eIssn": "18672485",
#                         "prism:issn": "18672477",
#                         "prism:issueIdentifier": "4",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Geoheritage",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85176104737",
#                         "prism:volume": "15",
#                         "source-id": "19600157344",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "citedby-count": "0",
#                         "dc:creator": "Hoek M.",
#                         "dc:identifier": "SCOPUS_ID:85173445512",
#                         "dc:title": "Tech for good: Imagine solving the world? Greatest challenges",
#                         "eid": "2-s2.0-85173445512",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85173445512",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85173445512?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85173445512&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85173445512&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Book",
#                         "prism:coverDate": "2023-11-29",
#                         "prism:coverDisplayDate": "29 November 2023",
#                         "prism:doi": "10.4324/9781003392064",
#                         "prism:isbn": [
#                               {
#                                     "$": "9781003392064",
#                                     "@_fa": "true"
#                               },
#                               {
#                                     "$": "9781032490731",
#                                     "@_fa": "true"
#                               }
#                         ],
#                         "prism:pageRange": "1-364",
#                         "prism:publicationName": "Tech For Good: Imagine Solving the World? Greatest Challenges",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85173445512",
#                         "source-id": "21101181802",
#                         "subtype": "bk",
#                         "subtypeDescription": "Book"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Hong Kong",
#                                     "affiliation-country": "Hong Kong",
#                                     "affilname": "City University of Hong Kong"
#                               }
#                         ],
#                         "article-number": "107715",
#                         "citedby-count": "0",
#                         "dc:creator": "Xu H.",
#                         "dc:identifier": "SCOPUS_ID:85171132950",
#                         "dc:title": "LOD2 for energy simulation (LOD2ES) for CityGML: A novel level of details model for IFC-based building features extraction and energy simulation",
#                         "eid": "2-s2.0-85171132950",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85171132950",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85171132950?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85171132950&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85171132950&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S2352710223018958",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "pii": "S2352710223018958",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-11-01",
#                         "prism:coverDisplayDate": "1 November 2023",
#                         "prism:doi": "10.1016/j.jobe.2023.107715",
#                         "prism:eIssn": "23527102",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Journal of Building Engineering",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85171132950",
#                         "prism:volume": "78",
#                         "source-id": "21100389518",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Pachuca",
#                                     "affiliation-country": "Mexico",
#                                     "affilname": "Universidad Polit\u00e9cnica de Pachuca"
#                               }
#                         ],
#                         "citedby-count": "0",
#                         "dc:creator": "Ruiz-Vanoye J.A.",
#                         "dc:identifier": "SCOPUS_ID:85177610748",
#                         "dc:title": "Management, technology, and economic growth in smart and sustainable cities",
#                         "eid": "2-s2.0-85177610748",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85177610748",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85177610748?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85177610748&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85177610748&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Book",
#                         "prism:coverDate": "2023-10-24",
#                         "prism:coverDisplayDate": "24 October 2023",
#                         "prism:doi": "10.4018/9798369303733",
#                         "prism:isbn": [
#                               {
#                                     "$": "9798369303757",
#                                     "@_fa": "true"
#                               },
#                               {
#                                     "$": "9798369303733",
#                                     "@_fa": "true"
#                               }
#                         ],
#                         "prism:pageRange": "1-341",
#                         "prism:publicationName": "Management, Technology, and Economic Growth in Smart and Sustainable Cities",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85177610748",
#                         "source-id": "21101187906",
#                         "subtype": "bk",
#                         "subtypeDescription": "Book"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Kayseri",
#                                     "affiliation-country": "Turkey",
#                                     "affilname": "Kayseri University"
#                               }
#                         ],
#                         "article-number": "2464",
#                         "citedby-count": "0",
#                         "dc:creator": "Y\u0131lmaz M.",
#                         "dc:identifier": "SCOPUS_ID:85175073728",
#                         "dc:title": "Investigation of Real Estate Tax Leakage Loss Rates with ANNs",
#                         "eid": "2-s2.0-85175073728",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85175073728",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85175073728?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85175073728&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85175073728&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-10-01",
#                         "prism:coverDisplayDate": "October 2023",
#                         "prism:doi": "10.3390/buildings13102464",
#                         "prism:eIssn": "20755309",
#                         "prism:issueIdentifier": "10",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Buildings",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85175073728",
#                         "prism:volume": "13",
#                         "source-id": "26980",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Hamirpur",
#                                     "affiliation-country": "India",
#                                     "affilname": "National Institute of Technology Hamirpur"
#                               }
#                         ],
#                         "citedby-count": "0",
#                         "dc:creator": "Singh S.",
#                         "dc:identifier": "SCOPUS_ID:85173965875",
#                         "dc:title": "Hydrogeophysical Survey for Assessment of Groundwater Budget and Aquifer Protection in Hilly Terrain",
#                         "eid": "2-s2.0-85173965875",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85173965875",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85173965875?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85173965875&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85173965875&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-10-01",
#                         "prism:coverDisplayDate": "October 2023",
#                         "prism:doi": "10.22044/jme.2023.12816.2329",
#                         "prism:eIssn": "22518606",
#                         "prism:issn": "22518592",
#                         "prism:issueIdentifier": "4",
#                         "prism:pageRange": "1061-1079",
#                         "prism:publicationName": "Journal of Mining and Environment",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85173965875",
#                         "prism:volume": "14",
#                         "source-id": "21101073709",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Istanbul",
#                                     "affiliation-country": "Turkey",
#                                     "affilname": "\u0130stanbul Teknik \u00dcniversitesi"
#                               }
#                         ],
#                         "citedby-count": "1",
#                         "dc:creator": "Mete M.O.",
#                         "dc:identifier": "SCOPUS_ID:85139904399",
#                         "dc:title": "A Hybrid Approach for Mass Valuation of Residential Properties through Geographic Information Systems and Machine Learning Integration",
#                         "eid": "2-s2.0-85139904399",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85139904399",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85139904399?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85139904399&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85139904399&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-10-01",
#                         "prism:coverDisplayDate": "October 2023",
#                         "prism:doi": "10.1111/gean.12350",
#                         "prism:eIssn": "15384632",
#                         "prism:issn": "00167363",
#                         "prism:issueIdentifier": "4",
#                         "prism:pageRange": "535-559",
#                         "prism:publicationName": "Geographical Analysis",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85139904399",
#                         "prism:volume": "55",
#                         "source-id": "28671",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "citedby-count": "0",
#                         "dc:creator": "Ozarisoy B.",
#                         "dc:identifier": "SCOPUS_ID:85175499418",
#                         "dc:title": "Energy policy design in the eastern mediterranean basin: A roadmap to energy efficiency",
#                         "eid": "2-s2.0-85175499418",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85175499418",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85175499418?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85175499418&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85175499418&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Book",
#                         "prism:coverDate": "2023-09-28",
#                         "prism:coverDisplayDate": "28 September 2023",
#                         "prism:doi": "10.4324/9781003393092",
#                         "prism:isbn": [
#                               {
#                                     "$": "9781000921823",
#                                     "@_fa": "true"
#                               },
#                               {
#                                     "$": "9781032493053",
#                                     "@_fa": "true"
#                               }
#                         ],
#                         "prism:pageRange": "1-524",
#                         "prism:publicationName": "Energy Policy Design in the Eastern Mediterranean Basin: A Roadmap to Energy Efficiency",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85175499418",
#                         "source-id": "21101185234",
#                         "subtype": "bk",
#                         "subtypeDescription": "Book"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Vancouver",
#                                     "affiliation-country": "Canada",
#                                     "affilname": "University Canada West"
#                               }
#                         ],
#                         "citedby-count": "0",
#                         "dc:creator": "Roache D.A.M.",
#                         "dc:identifier": "SCOPUS_ID:85175667493",
#                         "dc:title": "Transformational Leadership Styles for Global Leaders: Management and Communication Strategies",
#                         "eid": "2-s2.0-85175667493",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85175667493",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85175667493?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85175667493&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85175667493&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Book",
#                         "prism:coverDate": "2023-09-26",
#                         "prism:coverDisplayDate": "26 September 2023",
#                         "prism:doi": "10.4018/979-8-3693-1380-0",
#                         "prism:isbn": [
#                               {
#                                     "$": "9798369313817",
#                                     "@_fa": "true"
#                               },
#                               {
#                                     "$": "9798369313800",
#                                     "@_fa": "true"
#                               }
#                         ],
#                         "prism:pageRange": "1-545",
#                         "prism:publicationName": "Transformational Leadership Styles for Global Leaders: Management and Communication Strategies",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85175667493",
#                         "source-id": "21101185309",
#                         "subtype": "bk",
#                         "subtypeDescription": "Book"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Recife",
#                                     "affiliation-country": "Brazil",
#                                     "affilname": "Federal University of Penambuco"
#                               }
#                         ],
#                         "article-number": "102896",
#                         "citedby-count": "0",
#                         "dc:creator": "Belmiro C.",
#                         "dc:identifier": "SCOPUS_ID:85168374032",
#                         "dc:title": "Understanding the land use intensity of residential buildings in Brazil: An ensemble machine learning approach",
#                         "eid": "2-s2.0-85168374032",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfree2read"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Bronze"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85168374032",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85168374032?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85168374032&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85168374032&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S019739752300156X",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "pii": "S019739752300156X",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-09-01",
#                         "prism:coverDisplayDate": "September 2023",
#                         "prism:doi": "10.1016/j.habitatint.2023.102896",
#                         "prism:issn": "01973975",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Habitat International",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85168374032",
#                         "prism:volume": "139",
#                         "source-id": "13760",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Raleigh",
#                                     "affiliation-country": "United States",
#                                     "affilname": "NC State University"
#                               }
#                         ],
#                         "article-number": "100267",
#                         "citedby-count": "5",
#                         "dc:creator": "Xu X.",
#                         "dc:identifier": "SCOPUS_ID:85163172049",
#                         "dc:title": "A Gaussian process regression machine learning model for forecasting retail property prices with Bayesian optimizations and cross-validation",
#                         "eid": "2-s2.0-85163172049",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85163172049",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85163172049?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163172049&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85163172049&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S2772662223001078",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "pii": "S2772662223001078",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-09-01",
#                         "prism:coverDisplayDate": "September 2023",
#                         "prism:doi": "10.1016/j.dajour.2023.100267",
#                         "prism:eIssn": "27726622",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Decision Analytics Journal",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85163172049",
#                         "prism:volume": "8",
#                         "source-id": "21101098756",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Regensburg",
#                                     "affiliation-country": "Germany",
#                                     "affilname": "Universit\u00e4t Regensburg"
#                               }
#                         ],
#                         "citedby-count": "9",
#                         "dc:creator": "Lorenz F.",
#                         "dc:identifier": "SCOPUS_ID:85132747566",
#                         "dc:title": "Interpretable machine learning for real estate market analysis",
#                         "eid": "2-s2.0-85132747566",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherhybridgold"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryvor"
#                                     },
#                                     {
#                                           "$": "repositoryam"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Hybrid Gold"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
# ...
#                                     {
#                                           "$": "Gold"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85160323109",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85160323109?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85160323109&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85160323109&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-05-01",
#                         "prism:coverDisplayDate": "May 2023",
#                         "prism:doi": "10.3390/ijgi12050200",
#                         "prism:eIssn": "22209964",
#                         "prism:issueIdentifier": "5",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "ISPRS International Journal of Geo-Information",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85160323109",
#                         "prism:volume": "12",
#                         "source-id": "21100427639",
#                         "subtype": "re",
#                         "subtypeDescription": "Review"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Vilnius",
#                                     "affiliation-country": "Lithuania",
#                                     "affilname": "Vilniaus Gedimino Technikos Universitetas"
#                               }
#                         ],
#                         "article-number": "5453",
#                         "citedby-count": "1",
#                         "dc:creator": "Velykorusova A.",
#                         "dc:identifier": "SCOPUS_ID:85159354367",
#                         "dc:title": "Intelligent Multi-Criteria Decision Support for Renovation Solutions for a Building Based on Emotion Recognition by Applying the COPRAS Method and BIM Integration",
#                         "eid": "2-s2.0-85159354367",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryvor"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85159354367",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85159354367?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159354367&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85159354367&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-05-01",
#                         "prism:coverDisplayDate": "May 2023",
#                         "prism:doi": "10.3390/app13095453",
#                         "prism:eIssn": "20763417",
#                         "prism:issueIdentifier": "9",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Applied Sciences (Switzerland)",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85159354367",
#                         "prism:volume": "13",
#                         "source-id": "21100829268",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Melbourne",
#                                     "affiliation-country": "Australia",
#                                     "affilname": "Monash University"
#                               }
#                         ],
#                         "citedby-count": "1",
#                         "dc:creator": "Wan W.X.",
#                         "dc:identifier": "SCOPUS_ID:85143233595",
#                         "dc:title": "Testing machine learning systems in real estate",
#                         "eid": "2-s2.0-85143233595",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfree2read"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Bronze"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85143233595",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85143233595?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85143233595&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85143233595&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-05-01",
#                         "prism:coverDisplayDate": "May 2023",
#                         "prism:doi": "10.1111/1540-6229.12416",
#                         "prism:eIssn": "15406229",
#                         "prism:issn": "10808620",
#                         "prism:issueIdentifier": "3",
#                         "prism:pageRange": "754-778",
#                         "prism:publicationName": "Real Estate Economics",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85143233595",
#                         "prism:volume": "51",
#                         "source-id": "24900",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Subang Jaya",
#                                     "affiliation-country": "Malaysia",
#                                     "affilname": "Taylor's University Malaysia"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Suva",
#                                     "affiliation-country": "Fiji",
#                                     "affilname": "University of the South Pacific"
#                               }
#                         ],
#                         "citedby-count": "0",
#                         "dc:creator": "Gaur L.",
#                         "dc:identifier": "SCOPUS_ID:85163458236",
#                         "dc:title": "Emerging trends, techniques, and applications in geospatial data science",
#                         "eid": "2-s2.0-85163458236",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85163458236",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85163458236?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163458236&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85163458236&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Book",
#                         "prism:coverDate": "2023-04-24",
#                         "prism:coverDisplayDate": "24 April 2023",
#                         "prism:doi": "10.4018/978-1-6684-7319-1",
#                         "prism:isbn": [
#                               {
#                                     "$": "9781668473214",
#                                     "@_fa": "true"
#                               },
#                               {
#                                     "$": "9781668473191",
#                                     "@_fa": "true"
#                               }
#                         ],
#                         "prism:pageRange": "1-309",
#                         "prism:publicationName": "Emerging Trends, Techniques, and Applications in Geospatial Data Science",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85163458236",
#                         "source-id": "21101161806",
#                         "subtype": "bk",
#                         "subtypeDescription": "Book"
#                   }
#             ],
#             "link": [
#                   {
#                         "@_fa": "true",
#                         "@href": "https://api.elsevier.com/content/search/scopus?start=0&count=25&query=data+mining+housing+automated+valuation+model",
#                         "@ref": "self",
#                         "@type": "application/json"
#                   },
#                   {
#                         "@_fa": "true",
#                         "@href": "https://api.elsevier.com/content/search/scopus?start=0&count=25&query=data+mining+housing+automated+valuation+model",
#                         "@ref": "first",
#                         "@type": "application/json"
#                   },
#                   {
#                         "@_fa": "true",
#                         "@href": "https://api.elsevier.com/content/search/scopus?start=25&count=25&query=data+mining+housing+automated+valuation+model",
#                         "@ref": "next",
#                         "@type": "application/json"
#                   },
#                   {
#                         "@_fa": "true",
#                         "@href": "https://api.elsevier.com/content/search/scopus?start=310&count=25&query=data+mining+housing+automated+valuation+model",
#                         "@ref": "last",
#                         "@type": "application/json"
#                   }
#             ],
#             "opensearch:Query": {
#                   "@role": "request",
#                   "@searchTerms": "data mining housing automated valuation model",
#                   "@startPage": "0"
#             },
#             "opensearch:itemsPerPage": "25",
#             "opensearch:startIndex": "0",
#             "opensearch:totalResults": "335"
#       }
# }

# %%
results["search-results"]['entry'][0]["affiliation"]
# Out:
# [{'@_fa': 'true',
#   'affilname': 'Artvin Coruh University, Turkey',
#   'affiliation-city': 'Artvin',
#   'affiliation-country': 'Turkey'}]

# %%
'affiliation' in results["search-results"]['entry'][0]
# Out:
# True

# %% [markdown]
# ### Exploratório: 3. Número total de resultados obtidos na pesquisa

# %%
number_of_articles_retrieved = results["search-results"]["opensearch:totalResults"]
number_of_articles_retrieved
# Out:
# '335'

# %%
number_of_articles_perResultPage = results["search-results"]["opensearch:itemsPerPage"]
number_of_articles_perResultPage
# Out:
# '25'

# %% [markdown]
# ### Exploratório: 4. Obter dados de cada um dos resultados de pesquisa e transformar numa estrutura de dados amigável (pandas -» data.frame )

# %% [markdown]
# #### Opção 1

# %%
df = pd.DataFrame.from_records(results["search-results"]['entry'] )
df[:3]
# Out:
#    @_fa                                               link  \
# 0  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 1  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 2  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
#
#                                            prism:url          dc:identifier  \
# 0  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85175657733
# 1  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85169292928
# 2  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85176104737
#
#                   eid                                           dc:title  \
# 0  2-s2.0-85175657733  Selecting the ideal sustainable green strategy...
# 1  2-s2.0-85169292928  Improving hedonic housing price models by inte...
# 2  2-s2.0-85176104737  Remnants of a Young Monogenetic Volcanic Field...
#
#       dc:creator                              prism:publicationName  \
# 0     Aytekin A.  Engineering Applications of Artificial Intelli...
# 1  Rey-Blanco D.                   Expert Systems with Applications
# 2       Foote A.                                        Geoheritage
#
#   prism:issn prism:volume  ... subtypeDescription article-number    source-id  \
# 0   09521976          127  ...            Article         107347        24182
# 1   09574174          235  ...            Article         121059        24201
# 2   18672477           15  ...            Article            131  19600157344
#
#   openaccess openaccessFlag  \
# 0          0          False
# 1          1           True
# 2          1           True
#
#                                           freetoread  \
# 0                                                NaN
# 1  {'value': [{'$': 'all'}, {'$': 'publisherhybri...
# 2  {'value': [{'$': 'all'}, {'$': 'publisherhybri...
#
#                                      freetoreadLabel prism:eIssn  \
# 0                                                NaN         NaN
# 1  {'value': [{'$': 'All Open Access'}, {'$': 'Hy...         NaN
# 2  {'value': [{'$': 'All Open Access'}, {'$': 'Hy...    18672485
#
#   prism:issueIdentifier prism:isbn
# 0                   NaN        NaN
# 1                   NaN        NaN
# 2                     4        NaN
#
# [3 rows x 29 columns]

# %% [markdown]
# #### Opção 2

# %%
df = pd.json_normalize(results["search-results"],['entry'] )
df[:3]
# Out:
#    @_fa                                               link  \
# 0  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 1  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 2  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
#
#                                            prism:url          dc:identifier  \
# 0  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85175657733
# 1  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85169292928
# 2  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85176104737
#
#                   eid                                           dc:title  \
# 0  2-s2.0-85175657733  Selecting the ideal sustainable green strategy...
# 1  2-s2.0-85169292928  Improving hedonic housing price models by inte...
# 2  2-s2.0-85176104737  Remnants of a Young Monogenetic Volcanic Field...
#
#       dc:creator                              prism:publicationName  \
# 0     Aytekin A.  Engineering Applications of Artificial Intelli...
# 1  Rey-Blanco D.                   Expert Systems with Applications
# 2       Foote A.                                        Geoheritage
#
#   prism:issn prism:volume  ... subtypeDescription article-number    source-id  \
# 0   09521976          127  ...            Article         107347        24182
# 1   09574174          235  ...            Article         121059        24201
# 2   18672477           15  ...            Article            131  19600157344
#
#   openaccess openaccessFlag                              freetoread.value  \
# 0          0          False                                           NaN
# 1          1           True  [{'$': 'all'}, {'$': 'publisherhybridgold'}]
# 2          1           True  [{'$': 'all'}, {'$': 'publisherhybridgold'}]
#
#                               freetoreadLabel.value prism:eIssn  \
# 0                                               NaN         NaN
# 1  [{'$': 'All Open Access'}, {'$': 'Hybrid Gold'}]         NaN
# 2  [{'$': 'All Open Access'}, {'$': 'Hybrid Gold'}]    18672485
#
#   prism:issueIdentifier prism:isbn
# 0                   NaN        NaN
# 1                   NaN        NaN
# 2                     4        NaN
#
# [3 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['@_fa', 'link', 'prism:url', 'dc:identifier', 'eid', 'dc:title',
#        'dc:creator', 'prism:publicationName', 'prism:issn', 'prism:volume',
#        'prism:pageRange', 'prism:coverDate', 'prism:coverDisplayDate',
#        'prism:doi', 'pii', 'citedby-count', 'affiliation',
#        'prism:aggregationType', 'subtype', 'subtypeDescription',
#        'article-number', 'source-id', 'openaccess', 'openaccessFlag',
#        'freetoread.value', 'freetoreadLabel.value', 'prism:eIssn',
#        'prism:issueIdentifier', 'prism:isbn'],
#       dtype='object')

# %% [markdown]
# ### Exploratório: 5. Aceder a dados em diferentes níveis hierárquicos

# %%
df_affiliation = pd.json_normalize(results["search-results"],['entry', 'affiliation'] )
df_affiliation.columns
#df['prism:doi']
#df_affiliation
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pauloricardolb\Documents\mambaforge\envs\myEnvICD\Lib\site-packages\pandas\io\json\_normalize.py:398, in json_normalize.<locals>._pull_field(js, spec, extract_record)
#     397     else:
# --> 398         result = result[spec]
#     399 except KeyError as e:
#
# KeyError: 'affiliation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\pauloricardolb\OneDrive - Universidade de Aveiro\TRABALHO_AULAS\AL20232024\ICD\projICD\notebooks\ICD2324_TextMining_00_CollectData_on.ipynb Cell 31 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pauloricardolb/OneDrive%20-%20Universidade%20de%20Aveiro/TRABALHO_AULAS/AL20232024/ICD/projICD/notebooks/ICD2324_TextMining_00_CollectData_on.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> df_affiliation = pd.json_normalize(results["search-results"],['entry', 'affiliation'] )
#       <a href='vscode-notebook-cell:/c%3A/Users/pauloricardolb/OneDrive%20-%20Universidade%20de%20Aveiro/TRABALHO_AULAS/AL20232024/ICD/projICD/notebooks/ICD2324_TextMining_00_CollectData_on.ipynb#X41sZmlsZQ%3D%3D?line=1'>2</a> df_affiliation.columns
#
# File c:\Users\pauloricardolb\Documents\mambaforge\envs\myEnvICD\Lib\site-packages\pandas\io\json\_normalize.py:517, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     514                 meta_vals[key].append(meta_val)
#     515             records.extend(recs)
# --> 517 _recursive_extract(data, record_path, {}, level=0)
#     519 result = DataFrame(records)
#     521 if record_prefix is not None:
#
# File c:\Users\pauloricardolb\Documents\mambaforge\envs\myEnvICD\Lib\site-packages\pandas\io\json\_normalize.py:496, in json_normalize.<locals>._recursive_extract(data, path, seen_meta, level)
#     493             if level + 1 == len(val):
#     494                 seen_meta[key] = _pull_field(obj, val[-1])
# --> 496         _recursive_extract(obj[path[0]], path[1:], seen_meta, level=level + 1)
#     497 else:
#     498     for obj in data:
#
# File c:\Users\pauloricardolb\Documents\mambaforge\envs\myEnvICD\Lib\site-packages\pandas\io\json\_normalize.py:499, in json_normalize.<locals>._recursive_extract(data, path, seen_meta, level)
#     497 else:
#     498     for obj in data:
# --> 499         recs = _pull_records(obj, path[0])
#     500         recs = [
#     501             nested_to_record(r, sep=sep, max_level=max_level)
#     502             if isinstance(r, dict)
#     503             else r
#     504             for r in recs
#     505         ]
#     507         # For repeating the metadata later
#
# File c:\Users\pauloricardolb\Documents\mambaforge\envs\myEnvICD\Lib\site-packages\pandas\io\json\_normalize.py:421, in json_normalize.<locals>._pull_records(js, spec)
#     415 def _pull_records(js: dict[str, Any], spec: list | str) -> list:
#     416     """
#     417     Internal function to pull field for records, and similar to
#     418     _pull_field, but require to return list. And will raise error
#     419     if has non iterable value.
#     420     """
# --> 421     result = _pull_field(js, spec, extract_record=True)
#     423     # GH 31507 GH 30145, GH 26284 if result is not list, raise TypeError if not
#     424     # null, otherwise return an empty list
#     425     if not isinstance(result, list):
#
# File c:\Users\pauloricardolb\Documents\mambaforge\envs\myEnvICD\Lib\site-packages\pandas\io\json\_normalize.py:401, in json_normalize.<locals>._pull_field(js, spec, extract_record)
#     399 except KeyError as e:
#     400     if extract_record:
# --> 401         raise KeyError(
#     402             f"Key {e} not found. If specifying a record_path, all elements of "
#     403             f"data should have the path."
#     404         ) from e
#     405     if errors == "ignore":
#     406         return np.nan
#
# KeyError: "Key 'affiliation' not found. If specifying a record_path, all elements of data should have the path."

# %%
df_affiliation[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\pauloricardolb\OneDrive - Universidade de Aveiro\TRABALHO_AULAS\AL20232024\ICD\projICD\notebooks\ICD2324_TextMining_00_CollectData_on.ipynb Cell 31 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pauloricardolb/OneDrive%20-%20Universidade%20de%20Aveiro/TRABALHO_AULAS/AL20232024/ICD/projICD/notebooks/ICD2324_TextMining_00_CollectData_on.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> df_affiliation[:5]
#
# NameError: name 'df_affiliation' is not defined

# %% [markdown]
# ### Exploratório: 5.1 Aceder a dados em diferentes níveis hierárquicos »» POSSÍVEIS DIFICULDADES
#
# Por vezes, nos resultados de pesquisa alguns items podem não conter certos elementos / informação codificada em níveis hierárquicos
# inferiores do json.
# Por exemplo, a informação sobre a afiliação dos autores pode estar omissa.
# Nestes casos, ao usar a função "pd.json_normalize" para navegar para níveis inferiores pode devolver um erro e inviabilizar o processo automatizado (isto porque a função
# "json_normalize" não permite uma forma expedita de solucionar este problema).
#
# Uma estratégia "naife" para ultrapassar esta questão passa por  transformar os dados para um data.frame considerando
# apenas o nível inicial da hierarquia do json (ou seja, utilizar a função json_normalize como fizemos para obter o objeto "df" anteriormente).
# Como verificamos, certos elementos do data.frame "df" armazenam dados em formato json / dicionário nas suas células.
# Ao invés de utilizarmos a função "json_normalize" para obtermos dados nos níveis hierárquicos inferiores, podemos desenvolver o nosso próprio algoritmo
# por forma a solucionarmos os problemas de dados omissos.
#
# Assim, uma implementação alternativa do ponto 5, para os dados da coluna "affiliation" seria algo como o que se ilustra no código seguinte.
#
# NOTA: reparem que se optarem por esta estratégia deverão alterar o código da seccção "Automatização global" em conformidade!

# %%
import numpy as np 

i=0 #devem utilizar um índice (de linha) para o qual existam dados na coluna "affiliation" do vosso data.frame «df»
AFF_COL_NAMES = pd.json_normalize(df.affiliation[0]).columns

df_affiliation_v2 = pd.DataFrame(columns=AFF_COL_NAMES)

for i in range(len(df.affiliation)) :
    if  type(df.affiliation.iloc[i]) == list :
        df_aux = pd.json_normalize(df.affiliation.iloc[i])
        df_affiliation_v2 = pd.concat([df_affiliation_v2, df_aux], ignore_index=True)

    else:
        emptydf = pd.DataFrame(np.nan, index=[0],columns=AFF_COL_NAMES) 
        df_affiliation_v2 = pd.concat([df_affiliation_v2,emptydf], ignore_index=True)

# %%
df_affiliation_v2[:5]
# Out:
#    @_fa                                      affilname affiliation-city  \
# 0  true                Artvin Coruh University, Turkey           Artvin
# 1  true  Universidad Nacional de Educacion a Distancia           Madrid
# 2  true                           Macquarie University           Sydney
# 3   NaN                                            NaN              NaN
# 4  true                   City University of Hong Kong        Hong Kong
#
#   affiliation-country
# 0              Turkey
# 1               Spain
# 2           Australia
# 3                 NaN
# 4           Hong Kong

# %% [markdown]
# ### Exploratório: 6. Combinar dados de diferentes hierarquias num único "data.frame"
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/08_combine_dataframes.html

# %%
FIELDS = ['dc:title', "prism:doi", 'dc:creator', 'citedby-count', 'openaccess']
df[FIELDS][:3]
# Out:
#                                             dc:title  \
# 0  Selecting the ideal sustainable green strategy...
# 1  Improving hedonic housing price models by inte...
# 2  Remnants of a Young Monogenetic Volcanic Field...
#
#                         prism:doi     dc:creator citedby-count openaccess
# 0  10.1016/j.engappai.2023.107347     Aytekin A.             0          0
# 1      10.1016/j.eswa.2023.121059  Rey-Blanco D.             1          1
# 2      10.1007/s12371-023-00897-8       Foote A.             0          1

# %%
df_all = pd.merge(df[FIELDS], df_affiliation_v2, how='left', left_index=True, right_index=True)
df_all[:3]
# Out:
#                                             dc:title  \
# 0  Selecting the ideal sustainable green strategy...
# 1  Improving hedonic housing price models by inte...
# 2  Remnants of a Young Monogenetic Volcanic Field...
#
#                         prism:doi     dc:creator citedby-count openaccess  \
# 0  10.1016/j.engappai.2023.107347     Aytekin A.             0          0
# 1      10.1016/j.eswa.2023.121059  Rey-Blanco D.             1          1
# 2      10.1007/s12371-023-00897-8       Foote A.             0          1
#
#    @_fa                                      affilname affiliation-city  \
# 0  true                Artvin Coruh University, Turkey           Artvin
# 1  true  Universidad Nacional de Educacion a Distancia           Madrid
# 2  true                           Macquarie University           Sydney
#
#   affiliation-country
# 0              Turkey
# 1               Spain
# 2           Australia

# %% [markdown]
# ## Automatização global
# Recolha de resultados individuais da API, seleção de dados de interesse, criação de estrutura de dados amigável

# %%
user_query = "data mining housing automated valuation model"
LEVEL0_FIELDS_OF_INTEREST = ['dc:title', "prism:doi", 'dc:creator']
AFFILIATION_FIELDS_OF_INTEREST = ['affilname', 'affiliation-city', 'affiliation-country']

df_results_list = pd.DataFrame(columns=LEVEL0_FIELDS_OF_INTEREST+AFFILIATION_FIELDS_OF_INTEREST)

cursor = "*"

for i in range(0,math.ceil(int(number_of_articles_retrieved)/int(number_of_articles_perResultPage))) :
#for i in range(0,1) :
    
    
    response = requests.get("https://api.elsevier.com/content/search/scopus",
                    headers={'Accept':'application/json',
                             'X-ELS-APIKey': MY_SCOPUS_API_KEY},
                         
                    params={    'query' : user_query,
                                'cursor' : cursor
                        }

                        )
    print(i)
    print(response.url)
    print(response.status_code)

    if(response.status_code == 200):
        results_aux = response.json()

        df_level1_aux = pd.DataFrame.from_records(results_aux["search-results"]['entry'] )
        df_level1_aux = df_level1_aux[LEVEL0_FIELDS_OF_INTEREST]
                
        df_affil_aux = pd.json_normalize(results["search-results"],['entry', 'affiliation'] )
        df_affil_aux = df_affil_aux[AFFILIATION_FIELDS_OF_INTEREST]
                
        df_all_aux = pd.merge(df_level1_aux, df_affil_aux, how='left', left_index=True, right_index=True)
        
        df_results_list = df_results_list.append(df_all_aux, ignore_index=True)


        cursor = results_aux["search-results"]["cursor"]['@next']
# Out:
# 0
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=%2A
# 200
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pauloricardolb\Documents\mambaforge\envs\myEnvICD\Lib\site-packages\pandas\io\json\_normalize.py:398, in json_normalize.<locals>._pull_field(js, spec, extract_record)
#     397     else:
# --> 398         result = result[spec]
#     399 except KeyError as e:
#
# KeyError: 'affiliation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\pauloricardolb\OneDrive - Universidade de Aveiro\TRABALHO_AULAS\AL20232024\ICD\projICD\notebooks\ICD2324_TextMining_00_CollectData_on.ipynb Cell 39 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/pauloricardolb/OneDrive%20-%20Universidade%20de%20Aveiro/TRABALHO_AULAS/AL20232024/ICD/projICD/notebooks/ICD2324_TextMining_00_CollectData_on.ipynb#X53sZmlsZQ%3D%3D?line=28'>29</a> df_level1_aux = pd.DataFrame.from_records(results_aux["search-results"]['entry'] )
#      <a href='vscode-notebook-cell:/c%3A/Users/pauloricardolb/OneDrive%20-%20Universidade%20de%20Aveiro/TRABALHO_AULAS/AL20232024/ICD/projICD/notebooks/ICD2324_TextMining_00_CollectData_on.ipynb#X53sZmlsZQ%3D%3D?line=29'>30</a> df_level1_aux = df_level1_aux[LEVEL0_FIELDS_OF_INTEREST]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pauloricardolb/OneDrive%20-%20Universidade%20de%20Aveiro/TRABALHO_AULAS/AL20232024/ICD/projICD/notebooks/ICD2324_TextMining_00_CollectData_on.ipynb#X53sZmlsZQ%3D%3D?line=31'>32</a> df_affil_aux = pd.json_normalize(results["search-results"],['entry', 'affiliation'] )
#      <a href='vscode-notebook-cell:/c%3A/Users/pauloricardolb/OneDrive%20-%20Universidade%20de%20Aveiro/TRABALHO_AULAS/AL20232024/ICD/projICD/notebooks/ICD2324_TextMining_00_CollectData_on.ipynb#X53sZmlsZQ%3D%3D?line=32'>33</a> df_affil_aux = df_affil_aux[AFFILIATION_FIELDS_OF_INTEREST]
#      <a href='vscode-notebook-cell:/c%3A/Users/pauloricardolb/OneDrive%20-%20Universidade%20de%20Aveiro/TRABALHO_AULAS/AL20232024/ICD/projICD/notebooks/ICD2324_TextMining_00_CollectData_on.ipynb#X53sZmlsZQ%3D%3D?line=34'>35</a> df_all_aux = pd.merge(df_level1_aux, df_affil_aux, how='left', left_index=True, right_index=True)
#
# File c:\Users\pauloricardolb\Documents\mambaforge\envs\myEnvICD\Lib\site-packages\pandas\io\json\_normalize.py:517, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     514                 meta_vals[key].append(meta_val)
#     515             records.extend(recs)
# --> 517 _recursive_extract(data, record_path, {}, level=0)
#     519 result = DataFrame(records)
#     521 if record_prefix is not None:
#
# File c:\Users\pauloricardolb\Documents\mambaforge\envs\myEnvICD\Lib\site-packages\pandas\io\json\_normalize.py:496, in json_normalize.<locals>._recursive_extract(data, path, seen_meta, level)
#     493             if level + 1 == len(val):
#     494                 seen_meta[key] = _pull_field(obj, val[-1])
# --> 496         _recursive_extract(obj[path[0]], path[1:], seen_meta, level=level + 1)
#     497 else:
#     498     for obj in data:
#
# File c:\Users\pauloricardolb\Documents\mambaforge\envs\myEnvICD\Lib\site-packages\pandas\io\json\_normalize.py:499, in json_normalize.<locals>._recursive_extract(data, path, seen_meta, level)
#     497 else:
#     498     for obj in data:
# --> 499         recs = _pull_records(obj, path[0])
#     500         recs = [
#     501             nested_to_record(r, sep=sep, max_level=max_level)
#     502             if isinstance(r, dict)
#     503             else r
#     504             for r in recs
#     505         ]
#     507         # For repeating the metadata later
#
# File c:\Users\pauloricardolb\Documents\mambaforge\envs\myEnvICD\Lib\site-packages\pandas\io\json\_normalize.py:421, in json_normalize.<locals>._pull_records(js, spec)
#     415 def _pull_records(js: dict[str, Any], spec: list | str) -> list:
#     416     """
#     417     Internal function to pull field for records, and similar to
#     418     _pull_field, but require to return list. And will raise error
#     419     if has non iterable value.
#     420     """
# --> 421     result = _pull_field(js, spec, extract_record=True)
#     423     # GH 31507 GH 30145, GH 26284 if result is not list, raise TypeError if not
#     424     # null, otherwise return an empty list
#     425     if not isinstance(result, list):
#
# File c:\Users\pauloricardolb\Documents\mambaforge\envs\myEnvICD\Lib\site-packages\pandas\io\json\_normalize.py:401, in json_normalize.<locals>._pull_field(js, spec, extract_record)
#     399 except KeyError as e:
#     400     if extract_record:
# --> 401         raise KeyError(
#     402             f"Key {e} not found. If specifying a record_path, all elements of "
#     403             f"data should have the path."
#     404         ) from e
#     405     if errors == "ignore":
#     406         return np.nan
#
# KeyError: "Key 'affiliation' not found. If specifying a record_path, all elements of data should have the path."

# %%
user_query = "data mining housing automated valuation model"
LEVEL0_FIELDS_OF_INTEREST = ['dc:title', "prism:doi", 'dc:creator']
AFFILIATION_FIELDS_OF_INTEREST = ['affilname', 'affiliation-city', 'affiliation-country']

df_results_list = pd.DataFrame(columns=LEVEL0_FIELDS_OF_INTEREST+AFFILIATION_FIELDS_OF_INTEREST)

cursor = "*"

for i in range(0,math.ceil(int(number_of_articles_retrieved)/int(number_of_articles_perResultPage))) :
#for i in range(0,1) :
    
    
    response = requests.get("https://api.elsevier.com/content/search/scopus",
                    headers={'Accept':'application/json',
                             'X-ELS-APIKey': MY_SCOPUS_API_KEY},
                         
                    params={    'query' : user_query,
                                'cursor' : cursor
                        }

                        )
    print(i)
    print(response.url)
    print(response.status_code)

    if(response.status_code == 200):
        results_aux = response.json()

        df_level1_aux = pd.DataFrame.from_records(results_aux["search-results"]['entry'] )
        df_level1_aux = df_level1_aux[LEVEL0_FIELDS_OF_INTEREST]

        print("Este valor" + str(len(results_aux["search-results"]['entry']) ) )
        
        df_affil_aux_out =pd.DataFrame(columns=AFF_COL_NAMES)

        for i in range(len(results_aux["search-results"]['entry'])) :

            if 'affiliation' in results["search-results"]['entry'][i]:

                print("Passou aqui")
                
                df_affil_aux_in = pd.json_normalize(results["search-results"]['entry'][i]['affiliation'])
                df_affil_aux_in = df_affil_aux_in[AFFILIATION_FIELDS_OF_INTEREST]
                df_affil_aux_out = pd.concat([df_affil_aux_in, df_affil_aux_out], axis=0, ignore_index=True)

                # 
                
                #df_results_list = pd.concat([df_results_list, df_all_aux], ignore_index=True)
                

            else:

                df_affil_aux_in = pd.DataFrame(np.nan, index=[0],columns=AFF_COL_NAMES)
                
        
        df_all_aux = pd.merge(df_level1_aux, df_affil_aux_out, how='left', left_index=True, right_index=True)
        df_results_list = pd.concat([df_results_list, df_all_aux], ignore_index=True)
        cursor = results_aux["search-results"]["cursor"]['@next']
# Out:
# 0
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=%2A
# 200
# Este valor25
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# 1
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=AoJYkZZNMjItczIuMC04NTE2MzQ1ODIzNg%3D%3D
# 200
# Este valor25
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# 2
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=AoJV%2FZVNMjItczIuMC04NTE2MTQ2NjYzNg%3D%3D
# 200
# Este valor25
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# 3
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=AoJdypFNMjItczIuMC04NTE0NzkzNTM5Ng%3D%3D
# 200
# Este valor25
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# 4
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=AoJepZFNMjItczIuMC04NTEzMjYxOTA5OQ%3D%3D
# 200
# Este valor25
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# 5
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=AoJVjJFNMjItczIuMC04NTE0MjQ4NzY5OQ%3D%3D
# 200
# Este valor25
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# 6
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=AoJd2YxNMjItczIuMC04NTEyMDA2MTA1MA%3D%3D
# 200
# Este valor25
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# 7
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=AoJVm4xNMjItczIuMC04NTEzMzA3NDUwNw%3D%3D
# 200
# Este valor25
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# 8
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=AoJV3IdNMjItczIuMC04NTA5MTEzNzExOA%3D%3D
# 200
# Este valor25
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# 9
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=AoJZ%2BIJNMjItczIuMC04NTA3NTQ5NTA3OQ%3D%3D
# 200
# Este valor25
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# 10
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=AoJdhv5MMjItczIuMC04NTA0OTU2MDAzMw%3D%3D
# 200
# Este valor25
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# 11
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=AoJV1%2FhMMjItczIuMC04NTAyNjc4MzExNA%3D%3D
# 200
# Este valor25
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# 12
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=AoJVhOpMMjItczIuMC04NDkzNjk0MDkwNQ%3D%3D
# 200
# Este valor25
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# 13
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&cursor=AoJV3sxMMjItczIuMC04NDg3NTk2MzM5Mw%3D%3D
# 200
# Este valor10
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui
# Passou aqui

# %%
len(results_aux["search-results"]['entry'])
# Out:
# 10

# %%
results["search-results"]['entry'][20]['affiliation']
# Out:
# [{'@_fa': 'true',
#   'affilname': 'Ben-Gurion University of the Negev',
#   'affiliation-city': 'Beer Sheva',
#   'affiliation-country': 'Israel'}]

# %%
pd.json_normalize(results["search-results"]['entry'][20]['affiliation'])
# Out:
#    @_fa                           affilname affiliation-city  \
# 0  true  Ben-Gurion University of the Negev       Beer Sheva
#
#   affiliation-country
# 0              Israel

# %%
"affiliation" in results["search-results"]['entry'][20]
# Out:
# True

# %%
jprint(response.json())
# Out:
# {
#       "search-results": {
#             "cursor": {
#                   "@current": "AoJV3sxMMjItczIuMC04NDg3NTk2MzM5Mw==",
#                   "@next": "AoJVuK9MMTItczIuMC0wMDM2OTE3OTQ0"
#             },
#             "entry": [
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Logan",
#                                     "affiliation-country": "United States",
#                                     "affilname": "Utah State University"
#                               }
#                         ],
#                         "citedby-count": "0",
#                         "dc:creator": "Kim Y.",
#                         "dc:identifier": "SCOPUS_ID:84870185340",
#                         "dc:title": "Towards an intelligent property valuation model: An exploratory and conceptual study",
#                         "eid": "2-s2.0-84870185340",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/84870185340",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/84870185340?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=84870185340&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=84870185340&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Conference Proceeding",
#                         "prism:coverDate": "2007-12-01",
#                         "prism:coverDisplayDate": "2007",
#                         "prism:isbn": [
#                               {
#                                     "$": "9781604233810",
#                                     "@_fa": "true"
#                               }
#                         ],
#                         "prism:pageRange": "152-160",
#                         "prism:publicationName": "Association for Information Systems - 13th Americas Conference on Information Systems, AMCIS 2007: Reaching New Heights",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/84870185340",
#                         "prism:volume": "1",
#                         "source-id": "21100496607",
#                         "subtype": "cp",
#                         "subtypeDescription": "Conference Paper"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": null,
#                                     "affiliation-country": "Sierra Leone",
#                                     "affilname": "Netherlands Environmental Assessment Agency"
#                               }
#                         ],
#                         "citedby-count": "410",
#                         "dc:creator": "Metz B.",
#                         "dc:identifier": "SCOPUS_ID:84884387204",
#                         "dc:title": "Climate change 2007 mitigation of climate change",
#                         "eid": "2-s2.0-84884387204",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/84884387204",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/84884387204?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=84884387204&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=84884387204&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Book",
#                         "prism:coverDate": "2007-01-01",
#                         "prism:coverDisplayDate": "1 January 2007",
#                         "prism:doi": "10.1017/CBO9780511546013",
#                         "prism:isbn": [
#                               {
#                                     "$": "9780511546013",
#                                     "@_fa": "true"
#                               },
#                               {
#                                     "$": "9780521880114",
#                                     "@_fa": "true"
#                               }
#                         ],
#                         "prism:pageRange": "1-861",
#                         "prism:publicationName": "Climate Change 2007 Mitigation of Climate Change",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/84884387204",
#                         "prism:volume": "9780521880114",
#                         "source-id": "21100380791",
#                         "subtype": "bk",
#                         "subtypeDescription": "Book"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Birmingham",
#                                     "affiliation-country": "United Kingdom",
#                                     "affilname": "University of Birmingham"
#                               }
#                         ],
#                         "citedby-count": "30",
#                         "dc:creator": "van der Horst D.",
#                         "dc:identifier": "SCOPUS_ID:33745889597",
#                         "dc:title": "Spatial cost-benefit thinking in multi-functional forestry; towards a framework for spatial targeting of policy interventions",
#                         "eid": "2-s2.0-33745889597",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/33745889597",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/33745889597?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=33745889597&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=33745889597&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S0921800905004659",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "pii": "S0921800905004659",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2006-08-05",
#                         "prism:coverDisplayDate": "5 August 2006",
#                         "prism:doi": "10.1016/j.ecolecon.2005.10.005",
#                         "prism:issn": "09218009",
#                         "prism:issueIdentifier": "1",
#                         "prism:pageRange": "171-180",
#                         "prism:publicationName": "Ecological Economics",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/33745889597",
#                         "prism:volume": "59",
#                         "source-id": "20290",
#                         "subtype": "sh",
#                         "subtypeDescription": "Short Survey"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Sao Leopoldo",
#                                     "affiliation-country": "Brazil",
#                                     "affilname": "Universidade do Vale do Rio dos Sinos"
#                               }
#                         ],
#                         "citedby-count": "44",
#                         "dc:creator": "Gonzalez M.",
#                         "dc:identifier": "SCOPUS_ID:33644541065",
#                         "dc:title": "Mass appraisal with genetic fuzzy rule-based systems",
#                         "eid": "2-s2.0-33644541065",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/33644541065",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/33644541065?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=33644541065&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=33644541065&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2006-03-06",
#                         "prism:coverDisplayDate": "2006",
#                         "prism:doi": "10.1108/02637470610643092",
#                         "prism:issn": "02637472",
#                         "prism:issueIdentifier": "1",
#                         "prism:pageRange": "20-30",
#                         "prism:publicationName": "Property Management",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/33644541065",
#                         "prism:volume": "24",
#                         "source-id": "144667",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Storrs",
#                                     "affiliation-country": "United States",
#                                     "affilname": "UConn School of Business"
#                               }
#                         ],
#                         "citedby-count": "88",
#                         "dc:creator": "Clapp J.M.",
#                         "dc:identifier": "SCOPUS_ID:33644599438",
#                         "dc:title": "Defining neighborhood boundaries: Are census tracts obsolete?",
#                         "eid": "2-s2.0-33644599438",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/33644599438",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/33644599438?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=33644599438&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=33644599438&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S0094119005000744",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "pii": "S0094119005000744",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2006-03-01",
#                         "prism:coverDisplayDate": "March 2006",
#                         "prism:doi": "10.1016/j.jue.2005.10.003",
#                         "prism:issn": "00941190",
#                         "prism:issueIdentifier": "2",
#                         "prism:pageRange": "259-284",
#                         "prism:publicationName": "Journal of Urban Economics",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/33644599438",
#                         "prism:volume": "59",
#                         "source-id": "24406",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Sao Leopoldo",
#                                     "affiliation-country": "Brazil",
#                                     "affilname": "Universidade do Vale do Rio dos Sinos"
#                               }
#                         ],
#                         "citedby-count": "6",
#                         "dc:creator": "Gonz\u00e1lez M.A.S.",
#                         "dc:identifier": "SCOPUS_ID:29544433205",
#                         "dc:title": "A new approach to spatial analysis in CAMA",
#                         "eid": "2-s2.0-29544433205",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/29544433205",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/29544433205?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=29544433205&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=29544433205&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2005-12-01",
#                         "prism:coverDisplayDate": "1 December 2005",
#                         "prism:doi": "10.1108/02637470510631474",
#                         "prism:issn": "02637472",
#                         "prism:issueIdentifier": "5",
#                         "prism:pageRange": "312-327",
#                         "prism:publicationName": "Property Management",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/29544433205",
#                         "prism:volume": "23",
#                         "source-id": "144667",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Nottingham",
#                                     "affiliation-country": "United Kingdom",
#                                     "affilname": "British Geological Survey"
#                               }
#                         ],
#                         "citedby-count": "119",
#                         "dc:creator": "Culshaw M.G.",
#                         "dc:identifier": "SCOPUS_ID:11944259737",
#                         "dc:title": "From concept towards reality: Developing the attributed 3D geological model of the shallow subsurface",
#                         "eid": "2-s2.0-11944259737",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryam"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/11944259737",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/11944259737?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=11944259737&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=11944259737&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2005-08-01",
#                         "prism:coverDisplayDate": "August 2005",
#                         "prism:doi": "10.1144/1470-9236/04-072",
#                         "prism:issn": "14709236",
#                         "prism:issueIdentifier": "3",
#                         "prism:pageRange": "231-284",
#                         "prism:publicationName": "Quarterly Journal of Engineering Geology and Hydrogeology",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/11944259737",
#                         "prism:volume": "38",
#                         "source-id": "16912",
#                         "subtype": "re",
#                         "subtypeDescription": "Review"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "College Station",
#                                     "affiliation-country": "United States",
#                                     "affilname": "Texas A&amp;M University"
#                               }
#                         ],
#                         "citedby-count": "38",
#                         "dc:creator": "Mannan M.S.",
#                         "dc:identifier": "SCOPUS_ID:85041120899",
#                         "dc:title": "Lees' Loss Prevention in the Process Industries: Hazard Identification, Assessment and Control: Third Edition",
#                         "eid": "2-s2.0-85041120899",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85041120899",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85041120899?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85041120899&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85041120899&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Book",
#                         "prism:coverDate": "2004-12-01",
#                         "prism:coverDisplayDate": "December 01, 2004",
#                         "prism:doi": "10.1016/B978-0-7506-7555-0.X5081-6",
#                         "prism:isbn": [
#                               {
#                                     "$": "9780750675550",
#                                     "@_fa": "true"
#                               }
#                         ],
#                         "prism:pageRange": "1-3567",
#                         "prism:publicationName": "Lees' Loss Prevention in the Process Industries: Hazard Identification, Assessment and Control: Third Edition",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85041120899",
#                         "prism:volume": "9780750675550",
#                         "source-id": "21100849177",
#                         "subtype": "bk",
#                         "subtypeDescription": "Book"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Hong Kong",
#                                     "affiliation-country": "Hong Kong",
#                                     "affilname": "City University of Hong Kong"
#                               }
#                         ],
#                         "citedby-count": "853",
#                         "dc:creator": "Chan L.K.",
#                         "dc:identifier": "SCOPUS_ID:0037121486",
#                         "dc:title": "Quality function deployment: A literature review",
#                         "eid": "2-s2.0-0037121486",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/0037121486",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/0037121486?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=0037121486&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=0037121486&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S0377221702001789",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "pii": "S0377221702001789",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2002-12-16",
#                         "prism:coverDisplayDate": "16 December 2002",
#                         "prism:doi": "10.1016/S0377-2217(02)00178-9",
#                         "prism:issn": "03772217",
#                         "prism:issueIdentifier": "3",
#                         "prism:pageRange": "463-497",
#                         "prism:publicationName": "European Journal of Operational Research",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/0037121486",
#                         "prism:volume": "143",
#                         "source-id": "22489",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Storrs",
#                                     "affiliation-country": "United States",
#                                     "affilname": "University of Connecticut"
#                               }
#                         ],
#                         "citedby-count": "47",
#                         "dc:creator": "Clapp J.",
#                         "dc:identifier": "SCOPUS_ID:0036917944",
#                         "dc:title": "Predicting spatial patterns of house prices using LPR and Bayesian smoothing",
#                         "eid": "2-s2.0-0036917944",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/0036917944",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/0036917944?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=0036917944&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=0036917944&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2002-01-01",
#                         "prism:coverDisplayDate": "Winter 2002",
#                         "prism:doi": "10.1111/1540-6229.00048",
#                         "prism:issn": "10808620",
#                         "prism:issueIdentifier": "4",
#                         "prism:pageRange": "505-532",
#                         "prism:publicationName": "Real Estate Economics",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/0036917944",
#                         "prism:volume": "30",
#                         "source-id": "24900",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   }
#             ],
#             "link": [
#                   {
#                         "@_fa": "true",
#                         "@href": "https://api.elsevier.com/content/search/scopus?cursor=AoJV3sxMMjItczIuMC04NDg3NTk2MzM5Mw%3D%3D&count=25&query=data+mining+housing+automated+valuation+model",
#                         "@ref": "self",
#                         "@type": "application/json"
#                   },
#                   {
#                         "@_fa": "true",
#                         "@href": "https://api.elsevier.com/content/search/scopus?cursor=*&count=25&query=data+mining+housing+automated+valuation+model",
#                         "@ref": "first",
#                         "@type": "application/json"
#                   },
#                   {
#                         "@_fa": "true",
#                         "@href": "https://api.elsevier.com/content/search/scopus?cursor=AoJVuK9MMTItczIuMC0wMDM2OTE3OTQ0&count=25&query=data+mining+housing+automated+valuation+model",
#                         "@ref": "next",
#                         "@type": "application/json"
#                   }
#             ],
#             "opensearch:Query": {
#                   "@role": "request",
#                   "@searchTerms": "data mining housing automated valuation model",
#                   "@startPage": ""
#             },
#             "opensearch:itemsPerPage": "25",
#             "opensearch:totalResults": "335"
#       }
# }

# %%
df_results_list[:200]
# Out:
#                                               dc:title  \
# 0    Selecting the ideal sustainable green strategy...
# 1    Improving hedonic housing price models by inte...
# 2    Remnants of a Young Monogenetic Volcanic Field...
# 3    Tech for good: Imagine solving the world? Grea...
# 4    LOD2 for energy simulation (LOD2ES) for CityGM...
# ..                                                 ...
# 195  Uncertainty in automated valuation models: Err...
# 196  Multi-source urban data fusion for property va...
# 197  Are MCDA methods benchmarkable? A comparative ...
# 198  Analysis of the energy balance of construction...
# 199  Automated valuation methods through the cost a...
#
#                           prism:doi     dc:creator  \
# 0    10.1016/j.engappai.2023.107347     Aytekin A.
# 1        10.1016/j.eswa.2023.121059  Rey-Blanco D.
# 2        10.1007/s12371-023-00897-8       Foote A.
# 3             10.4324/9781003392064        Hoek M.
# 4        10.1016/j.jobe.2023.107715          Xu H.
# ..                              ...            ...
# 195   10.1080/09599916.2020.1807587      Krause A.
# 196    10.1016/j.neucom.2020.05.013         Bin J.
# 197             10.3390/SYM12091549     Sałabun W.
# 198              10.3390/en13184843   Švajlenka J.
# 199              10.3390/su12187546      Arcuri N.
#
#                                          affilname affiliation-city  \
# 0                     Taylor's University Malaysia      Subang Jaya
# 1                  University of the South Pacific             Suva
# 2                                Monash University        Melbourne
# 3        Vilniaus Gedimino Technikos Universitetas          Vilnius
# 4                                        KU Leuven      3000 Leuven
# ..                                             ...              ...
# 195             Universidad Politécnica de Pachuca          Pachuca
# 196                   City University of Hong Kong        Hong Kong
# 197                           Macquarie University           Sydney
# 198  Universidad Nacional de Educacion a Distancia           Madrid
# 199                Artvin Coruh University, Turkey           Artvin
#
#     affiliation-country @_fa
# 0              Malaysia  NaN
# 1                  Fiji  NaN
# 2             Australia  NaN
# 3             Lithuania  NaN
# 4               Belgium  NaN
# ..                  ...  ...
# 195              Mexico  NaN
# 196           Hong Kong  NaN
# 197           Australia  NaN
# 198               Spain  NaN
# 199              Turkey  NaN
#
# [200 rows x 7 columns]

# %%
df_results_list.to_csv('../data/interim/df_results_list_records.csv', index=False)

# %% [markdown]
# # RECOLHA DE DADOS - Parte 2
# Recolha do contéudo dos artigos selecionados com a API Scopus
#
# NOTA: Como facilmente se verifica na [página](https://dev.elsevier.com/api_docs.html) os artigos completos
# estão disponíveis no serviço «ScienceDirect APIs», especificamente na API «Article Retrieval» (documentação [aqui](https://dev.elsevier.com/documentation/ArticleRetrievalAPI.wadl) )

# %% [markdown]
# ## Recolha de artigos completos
# Utilizando o identificador DOI

# %% [markdown]
# ### Análise exploratória

# %%
dois = df_results_list['prism:doi']
dois[:3]
# Out:
# 0           10.3390/su132313088
# 1    10.1186/s40537-021-00476-0
# 2    10.1016/j.jobe.2021.102636
# Name: prism:doi, dtype: object

# %%
response_article = requests.get("https://api.elsevier.com/content/article/doi/"+dois[2],
                    headers={ 'Accept':'application/json',
                             'X-ELS-APIKey': MY_API_KEY},
                         
                    params={   }

                        )
print(response_article.url)
print(response_article.status_code)
# Out:
# https://api.elsevier.com/content/article/doi/10.1016/j.jobe.2021.102636
# 200

# %%
#jprint(response_article.json())

# %%
type(dois)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Implementação global

# %%
# - a definir -

# %% [markdown]
# ## Recolha de resumos (dos artigos)
#
# Recolha do contéudo dos resumos dos artigos selecionados com a API Scopus (usando o identificador DOI guardado anteriormente)
#
# NOTA: Como facilmente se verifica na [página](https://dev.elsevier.com/api_docs.html) os resumos podem ser obtidos de duas formas:
# * Através do serviço «ScienceDirect APIs» e especificamente da API «Article Retrieval» (documentação [aqui](https://dev.elsevier.com/documentation/ArticleRetrievalAPI.wadl) ) descrita anteriormente
# * Através do serviço «Scopus APIs» (usado anteriormente para fazer a pesquisa) e especificamente da API «Abstract Retrieval» (documentação [aqui](https://dev.elsevier.com/documentation/AbstractRetrievalAPI.wadl))

# %% [markdown]
# ### Análise Exploratória

# %%
dois = df_results_list['prism:doi']

# %%
response_abst = requests.get("https://api.elsevier.com/content/abstract/doi/"+dois[114],
                    headers={#'Accept': 'application/json',
                    'Accept': 'application/json',
                    'X-ELS-APIKey': MY_API_KEY},
                    
                    params={   }
                )
print(response_abst.url)
print(response_abst.status_code)
# Out:
# https://api.elsevier.com/content/abstract/doi/10.1002/9781118280249
# 200

# %%
results_abstr = response_abst.json()
results_abstr
# Out:
# {'abstracts-retrieval-response': {'item': {'ait:process-info': {'ait:status': {'@state': 'update',
#      '@type': 'core',
#      '@stage': 'S300'},
#     'ait:date-delivered': {'@day': '06',
#      '@year': '2020',
#      '@timestamp': '2020-02-06T06:35:05.000005-05:00',
#      '@month': '02'},
#     'ait:date-sort': {'@day': '27', '@year': '2017', '@month': '11'}},
#    'bibrecord': {'head': {'citation-title': 'From the preface to the first edition',
#      'abstracts': None,
#      'citation-info': {'citation-type': {'@code': 'ed'},
#       'citation-language': {'@language': 'English', '@xml:lang': 'eng'}},
#      'source': {'sourcetitle-abbrev': 'Vet. Epidemiol.: Fourth Ed.',
#       'website': {'ce:e-address': {'$': 'http://onlinelibrary.wiley.com/book/10.1002/9781118280249',
#         '@type': 'email'}},
#       '@country': 'usa',
#       'translated-sourcetitle': {'@xml:lang': 'eng'},
#       'volisspag': {'pagerange': {'@first': 'xix'}},
#       '@type': 'b',
#       'publicationyear': {'@first': '2017'},
#       'isbn': [{'@level': 'volume',
#         '$': '9781118280249',
#         '@type': 'electronic',
#         '@length': '13'},
#        {'@level': 'volume',
#         '$': '9781118280287',
#         '@type': 'print',
#         '@length': '13'}],
#       'publisher': {'publishername': 'Wiley Blackwell'},
#       'sourcetitle': 'Veterinary Epidemiology: Fourth Edition',
#       '@srcid': '21100876345',
#       'publicationdate': {'month': '11',
#        'year': '2017',
#        'date-text': {'@xfab-added': 'true', '$': '27 November 2017'},
#        'day': '27'}},
#      'enhancement': {'classificationgroup': {'classifications': [{'@type': 'ASJC',
#          'classification': '3400'},
#         {'@type': 'SUBJABBR', 'classification': 'VETE'}]}}},
#     'item-info': {'copyright': {'$': 'Copyright 2018 Elsevier B.V., All rights reserved.',
#       '@type': 'Elsevier'},
#      'dbcollection': [{'$': 'SNBOOK'}, {'$': 'SCOPUS'}, {'$': 'Scopusbase'}],
#      'history': {'date-created': {'@day': '12',
#        '@year': '2018',
#        '@timestamp': 'BST 07:21:22',
#        '@month': '09'}},
#      'itemidlist': {'itemid': [{'$': '623817463', '@idtype': 'PUI'},
#        {'$': '912609259', '@idtype': 'CAR-ID'},
#        {'$': '2018144867', '@idtype': 'SNBOOK'},
#        {'$': '20182000126919', '@idtype': 'TPB-ID'},
#        {'$': '20181000686349', '@idtype': 'VTW-CAR-ID'},
#        {'$': '85052962587', '@idtype': 'SCP'},
#        {'$': '85052962587', '@idtype': 'SGR'}],
#       'ce:doi': '10.1002/9781118280249'}},
#     'tail': None}},
#   'coredata': {'srctype': 'b',
#    'eid': '2-s2.0-85052962587',
#    'prism:coverDate': '2017-11-27',
#    'prism:aggregationType': 'Book',
#    'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85052962587',
#    'subtypeDescription': 'Editorial',
#    'link': [{'@_fa': 'true',
#      '@rel': 'self',
#      '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85052962587'},
#     {'@_fa': 'true',
#      '@rel': 'scopus',
#      '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85052962587&origin=inward'},
#     {'@_fa': 'true',
#      '@rel': 'scopus-citedby',
#      '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85052962587&origin=inward'}],
#    'prism:isbn': [{'$': '9781118280249'}, {'$': '9781118280287'}],
#    'prism:publicationName': 'Veterinary Epidemiology: Fourth Edition',
#    'source-id': '21100876345',
#    'citedby-count': '0',
#    'subtype': 'ed',
#    'dc:title': 'From the preface to the first edition',
#    'openaccess': '0',
#    'openaccessFlag': 'false',
#    'prism:doi': '10.1002/9781118280249',
#    'prism:startingPage': 'xix',
#    'dc:identifier': 'SCOPUS_ID:85052962587',
#    'dc:publisher': 'Wiley Blackwell'},
#   'idxterms': None,
#   'language': {'@xml:lang': 'eng'},
#   'authkeywords': None,
#   'subject-areas': {'subject-area': [{'@_fa': 'true',
#      '$': 'Veterinary (all)',
#      '@code': '3400',
#      '@abbrev': 'VETE'}]},
#   'authors': None}}

# %%
jprint(response_abst.json())
# Out:
# {
#       "abstracts-retrieval-response": {
#             "authkeywords": null,
#             "authors": null,
#             "coredata": {
#                   "citedby-count": "0",
#                   "dc:identifier": "SCOPUS_ID:85052962587",
#                   "dc:publisher": "Wiley Blackwell",
#                   "dc:title": "From the preface to the first edition",
#                   "eid": "2-s2.0-85052962587",
#                   "link": [
#                         {
#                               "@_fa": "true",
#                               "@href": "https://api.elsevier.com/content/abstract/scopus_id/85052962587",
#                               "@rel": "self"
#                         },
#                         {
#                               "@_fa": "true",
#                               "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85052962587&origin=inward",
#                               "@rel": "scopus"
#                         },
#                         {
#                               "@_fa": "true",
#                               "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85052962587&origin=inward",
#                               "@rel": "scopus-citedby"
#                         }
#                   ],
#                   "openaccess": "0",
#                   "openaccessFlag": "false",
#                   "prism:aggregationType": "Book",
#                   "prism:coverDate": "2017-11-27",
#                   "prism:doi": "10.1002/9781118280249",
#                   "prism:isbn": [
#                         {
#                               "$": "9781118280249"
#                         },
#                         {
#                               "$": "9781118280287"
#                         }
#                   ],
#                   "prism:publicationName": "Veterinary Epidemiology: Fourth Edition",
#                   "prism:startingPage": "xix",
#                   "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85052962587",
#                   "source-id": "21100876345",
#                   "srctype": "b",
#                   "subtype": "ed",
#                   "subtypeDescription": "Editorial"
#             },
#             "idxterms": null,
#             "item": {
#                   "ait:process-info": {
#                         "ait:date-delivered": {
#                               "@day": "06",
#                               "@month": "02",
#                               "@timestamp": "2020-02-06T06:35:05.000005-05:00",
#                               "@year": "2020"
#                         },
#                         "ait:date-sort": {
#                               "@day": "27",
#                               "@month": "11",
#                               "@year": "2017"
#                         },
#                         "ait:status": {
#                               "@stage": "S300",
#                               "@state": "update",
#                               "@type": "core"
#                         }
#                   },
#                   "bibrecord": {
#                         "head": {
#                               "abstracts": null,
#                               "citation-info": {
#                                     "citation-language": {
#                                           "@language": "English",
#                                           "@xml:lang": "eng"
#                                     },
#                                     "citation-type": {
#                                           "@code": "ed"
#                                     }
#                               },
#                               "citation-title": "From the preface to the first edition",
#                               "enhancement": {
#                                     "classificationgroup": {
#                                           "classifications": [
#                                                 {
#                                                       "@type": "ASJC",
#                                                       "classification": "3400"
#                                                 },
#                                                 {
#                                                       "@type": "SUBJABBR",
#                                                       "classification": "VETE"
#                                                 }
#                                           ]
#                                     }
#                               },
#                               "source": {
#                                     "@country": "usa",
#                                     "@srcid": "21100876345",
#                                     "@type": "b",
#                                     "isbn": [
#                                           {
#                                                 "$": "9781118280249",
#                                                 "@length": "13",
#                                                 "@level": "volume",
#                                                 "@type": "electronic"
#                                           },
#                                           {
#                                                 "$": "9781118280287",
#                                                 "@length": "13",
#                                                 "@level": "volume",
#                                                 "@type": "print"
#                                           }
#                                     ],
#                                     "publicationdate": {
#                                           "date-text": {
#                                                 "$": "27 November 2017",
#                                                 "@xfab-added": "true"
#                                           },
#                                           "day": "27",
#                                           "month": "11",
#                                           "year": "2017"
#                                     },
#                                     "publicationyear": {
#                                           "@first": "2017"
#                                     },
#                                     "publisher": {
#                                           "publishername": "Wiley Blackwell"
#                                     },
#                                     "sourcetitle": "Veterinary Epidemiology: Fourth Edition",
#                                     "sourcetitle-abbrev": "Vet. Epidemiol.: Fourth Ed.",
#                                     "translated-sourcetitle": {
#                                           "@xml:lang": "eng"
#                                     },
#                                     "volisspag": {
#                                           "pagerange": {
#                                                 "@first": "xix"
#                                           }
#                                     },
#                                     "website": {
#                                           "ce:e-address": {
#                                                 "$": "http://onlinelibrary.wiley.com/book/10.1002/9781118280249",
#                                                 "@type": "email"
#                                           }
#                                     }
#                               }
#                         },
#                         "item-info": {
#                               "copyright": {
#                                     "$": "Copyright 2018 Elsevier B.V., All rights reserved.",
#                                     "@type": "Elsevier"
#                               },
#                               "dbcollection": [
#                                     {
#                                           "$": "SNBOOK"
#                                     },
#                                     {
#                                           "$": "SCOPUS"
#                                     },
#                                     {
#                                           "$": "Scopusbase"
#                                     }
#                               ],
#                               "history": {
#                                     "date-created": {
#                                           "@day": "12",
#                                           "@month": "09",
#                                           "@timestamp": "BST 07:21:22",
#                                           "@year": "2018"
#                                     }
#                               },
#                               "itemidlist": {
#                                     "ce:doi": "10.1002/9781118280249",
#                                     "itemid": [
#                                           {
#                                                 "$": "623817463",
#                                                 "@idtype": "PUI"
#                                           },
#                                           {
#                                                 "$": "912609259",
#                                                 "@idtype": "CAR-ID"
#                                           },
#                                           {
#                                                 "$": "2018144867",
#                                                 "@idtype": "SNBOOK"
#                                           },
#                                           {
#                                                 "$": "20182000126919",
#                                                 "@idtype": "TPB-ID"
#                                           },
#                                           {
#                                                 "$": "20181000686349",
#                                                 "@idtype": "VTW-CAR-ID"
#                                           },
#                                           {
#                                                 "$": "85052962587",
#                                                 "@idtype": "SCP"
#                                           },
#                                           {
#                                                 "$": "85052962587",
#                                                 "@idtype": "SGR"
#                                           }
#                                     ]
#                               }
#                         },
#                         "tail": null
#                   }
#             },
#             "language": {
#                   "@xml:lang": "eng"
#             },
#             "subject-areas": {
#                   "subject-area": [
#                         {
#                               "$": "Veterinary (all)",
#                               "@_fa": "true",
#                               "@abbrev": "VETE",
#                               "@code": "3400"
#                         }
#                   ]
#             }
#       }
# }

# %%
resumo = results_abstr["abstracts-retrieval-response"][ "coredata"]['dc:description']
resumo
# Out:
# '© 2021, Emerald Publishing Limited.Purpose: Real estate appraisals are becoming an increasingly important means of backing up financial operations based on the values of these kinds of assets. However, in very large databases, there is a reduction in the predictive capacity when traditional methods, such as multiple linear regression (MLR), are used. This paper aims to determine whether in these cases the application of data mining algorithms can achieve superior statistical results. First, real estate appraisal databases from five towns and cities in the State of Paraná, Brazil, were obtained from Caixa Econômica Federal bank. Design/methodology/approach: After initial validations, additional databases were generated with both real, transformed and nominal values, in clean and raw data. Each was assisted by the application of a wide range of data mining algorithms (multilayer perceptron, support vector regression, K-star, M5Rules and random forest), either isolated or combined (regression by discretization – logistic, bagging and stacking), with the use of 10-fold cross-validation in Weka software. Findings: The results showed more varied incremental statistical results with the use of algorithms than those obtained by MLR, especially when combined algorithms were used. The largest increments were obtained in databases with a large amount of data and in those where minor initial data cleaning was carried out. The paper also conducts a further analysis, including an algorithmic ranking based on the number of significant results obtained. Originality/value: The authors did not find similar studies or research studies conducted in Brazil.'

# %% [markdown]
# ### Implementação Global

# %%
dois = df_results_list['prism:doi']
dois
# Out:
# 0                     10.3390/su132313088
# 1              10.1186/s40537-021-00476-0
# 2              10.1016/j.jobe.2021.102636
# 3              10.1108/IJHMA-07-2020-0080
# 4             10.3390/geosciences11110480
#                       ...
# 179             10.1108/02637470510631474
# 180              10.1144/1470-9236/04-072
# 181    10.1016/B978-0-7506-7555-0.X5081-6
# 182         10.1016/S0377-2217(02)00178-9
# 183               10.1111/1540-6229.00048
# Name: prism:doi, Length: 184, dtype: object

# %%
abstract_list = []

i=0
for x in dois :
    print(x)
    response_abst = requests.get("https://api.elsevier.com/content/abstract/doi/"+str(x),
                    headers={
                    'Accept': 'application/json',
                    'X-ELS-APIKey': MY_API_KEY},
                    
                    params={   }
                )
    
    print(response_abst.url)
    print(response_abst.status_code)
    print(i)
    i=i+1

    if(response_abst.status_code == 200):
        results_abst = response_abst.json()
        if 'dc:description' in results_abst["abstracts-retrieval-response"][ "coredata"]:
            abstract_list.append( results_abst["abstracts-retrieval-response"][ "coredata"]['dc:description'] )
        else:
            abstract_list.append("NULL")
    else:
        abstract_list.append("NULL")
# Out:
# 10.3390/su132313088
# https://api.elsevier.com/content/abstract/doi/10.3390/su132313088
# 200
# 0
# here
# 10.1186/s40537-021-00476-0
# https://api.elsevier.com/content/abstract/doi/10.1186/s40537-021-00476-0
# 200
# 1
# here
# 10.1016/j.jobe.2021.102636
# https://api.elsevier.com/content/abstract/doi/10.1016/j.jobe.2021.102636
# 200
# 2
# here
# 10.1108/IJHMA-07-2020-0080
# https://api.elsevier.com/content/abstract/doi/10.1108/IJHMA-07-2020-0080
# 200
# 3
# here
# 10.3390/geosciences11110480
# https://api.elsevier.com/content/abstract/doi/10.3390/geosciences11110480
# 200
# 4
# here
# 10.1016/j.landurbplan.2021.104217
# https://api.elsevier.com/content/abstract/doi/10.1016/j.landurbplan.2021.104217
# 200
# 5
# here
# 10.1016/j.jclepro.2021.128824
# https://api.elsevier.com/content/abstract/doi/10.1016/j.jclepro.2021.128824
# 200
# 6
# here
# 10.3390/su132011450
# https://api.elsevier.com/content/abstract/doi/10.3390/su132011450
# 200
# 7
# here
# 10.3390/su132011259
# https://api.elsevier.com/content/abstract/doi/10.3390/su132011259
# 200
# 8
# here
# 10.1007/s12599-021-00715-x
# https://api.elsevier.com/content/abstract/doi/10.1007/s12599-021-00715-x
# 200
# 9
# here
# 10.1016/j.landurbplan.2021.104167
# https://api.elsevier.com/content/abstract/doi/10.1016/j.landurbplan.2021.104167
# 200
# 10
# here
# 10.1016/j.jocm.2021.100303
# https://api.elsevier.com/content/abstract/doi/10.1016/j.jocm.2021.100303
# 200
# 11
# here
# 10.1016/j.ufug.2021.127233
# https://api.elsevier.com/content/abstract/doi/10.1016/j.ufug.2021.127233
# 200
# 12
# here
# 10.1016/j.techfore.2021.120794
# https://api.elsevier.com/content/abstract/doi/10.1016/j.techfore.2021.120794
# 200
# 13
# here
# 10.3390/en14144078
# https://api.elsevier.com/content/abstract/doi/10.3390/en14144078
# 200
# 14
# here
# 10.1016/j.ufug.2021.127172
# https://api.elsevier.com/content/abstract/doi/10.1016/j.ufug.2021.127172
# 200
# 15
# here
# 10.1177/2399808320947729
# https://api.elsevier.com/content/abstract/doi/10.1177/2399808320947729
# 200
# 16
# here
# 10.1177/2399808320938796
# https://api.elsevier.com/content/abstract/doi/10.1177/2399808320938796
# 200
# 17
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 18
# 10.3390/su13116260
# https://api.elsevier.com/content/abstract/doi/10.3390/su13116260
# 200
# 19
# here
# 10.4324/9781003193951
# https://api.elsevier.com/content/abstract/doi/10.4324/9781003193951
# 200
# 20
# here
# 10.1007/s00521-020-05469-3
# https://api.elsevier.com/content/abstract/doi/10.1007/s00521-020-05469-3
# 200
# 21
# here
# 10.3390/land10040388
# https://api.elsevier.com/content/abstract/doi/10.3390/land10040388
# 200
# 22
# here
# 10.11834/jrs.20211018
# https://api.elsevier.com/content/abstract/doi/10.11834/jrs.20211018
# 200
# 23
# here
# 10.1080/00396265.2021.1996797
# https://api.elsevier.com/content/abstract/doi/10.1080/00396265.2021.1996797
# 200
# 24
# here
# 10.1007/s11146-021-09861-1
# https://api.elsevier.com/content/abstract/doi/10.1007/s11146-021-09861-1
# 200
# 25
# here
# 10.1007/s41324-021-00416-3
# https://api.elsevier.com/content/abstract/doi/10.1007/s41324-021-00416-3
# 200
# 26
# here
# 10.1002/widm.1435
# https://api.elsevier.com/content/abstract/doi/10.1002/widm.1435
# 200
# 27
# here
# 10.1007/978-3-030-86973-1_6
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-030-86973-1_6
# 200
# 28
# here
# 10.1080/15623599.2021.1975021
# https://api.elsevier.com/content/abstract/doi/10.1080/15623599.2021.1975021
# 200
# 29
# here
# 10.1007/s10901-021-09885-2
# https://api.elsevier.com/content/abstract/doi/10.1007/s10901-021-09885-2
# 200
# 30
# here
# 10.1007/s11146-021-09834-4
# https://api.elsevier.com/content/abstract/doi/10.1007/s11146-021-09834-4
# 200
# 31
# here
# 10.1108/JEDT-12-2020-0524
# https://api.elsevier.com/content/abstract/doi/10.1108/JEDT-12-2020-0524
# 200
# 32
# here
# 10.1108/PM-10-2020-0067
# https://api.elsevier.com/content/abstract/doi/10.1108/PM-10-2020-0067
# 200
# 33
# here
# 10.18335/region.v8i1.328
# https://api.elsevier.com/content/abstract/doi/10.18335/region.v8i1.328
# 200
# 34
# here
# 10.3390/land10060566
# https://api.elsevier.com/content/abstract/doi/10.3390/land10060566
# 200
# 35
# here
# 10.1108/SASBE-02-2021-0022
# https://api.elsevier.com/content/abstract/doi/10.1108/SASBE-02-2021-0022
# 200
# 36
# here
# 10.1080/09599916.2020.1858937
# https://api.elsevier.com/content/abstract/doi/10.1080/09599916.2020.1858937
# 200
# 37
# here
# 10.1007/s10901-021-09833-0
# https://api.elsevier.com/content/abstract/doi/10.1007/s10901-021-09833-0
# 200
# 38
# here
# 10.5659/JAIK.2021.37.1.191
# https://api.elsevier.com/content/abstract/doi/10.5659/JAIK.2021.37.1.191
# 200
# 39
# here
# 10.1111/gean.12283
# https://api.elsevier.com/content/abstract/doi/10.1111/gean.12283
# 200
# 40
# here
# 10.1007/978-3-030-48279-4_114
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-030-48279-4_114
# 200
# 41
# here
# 10.1007/978-3-030-48279-4_132
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-030-48279-4_132
# 200
# 42
# here
# 10.1007/978-3-030-49579-4_6
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-030-49579-4_6
# 200
# 43
# here
# 10.1016/j.landusepol.2020.104938
# https://api.elsevier.com/content/abstract/doi/10.1016/j.landusepol.2020.104938
# 200
# 44
# here
# 10.1080/00396265.2020.1771967
# https://api.elsevier.com/content/abstract/doi/10.1080/00396265.2020.1771967
# 200
# 45
# here
# 10.3390/s20236825
# https://api.elsevier.com/content/abstract/doi/10.3390/s20236825
# 200
# 46
# here
# 10.1016/j.landusepol.2020.105070
# https://api.elsevier.com/content/abstract/doi/10.1016/j.landusepol.2020.105070
# 200
# 47
# here
# 10.1109/UV50937.2020.9426215
# https://api.elsevier.com/content/abstract/doi/10.1109/UV50937.2020.9426215
# 200
# 48
# here
# 10.3390/land9100357
# https://api.elsevier.com/content/abstract/doi/10.3390/land9100357
# 200
# 49
# here
# 10.3390/SU12197904
# https://api.elsevier.com/content/abstract/doi/10.3390/SU12197904
# 200
# 50
# here
# 10.1080/09599916.2020.1807587
# https://api.elsevier.com/content/abstract/doi/10.1080/09599916.2020.1807587
# 200
# 51
# here
# 10.1016/j.neucom.2020.05.013
# https://api.elsevier.com/content/abstract/doi/10.1016/j.neucom.2020.05.013
# 200
# 52
# here
# 10.3390/SYM12091549
# https://api.elsevier.com/content/abstract/doi/10.3390/SYM12091549
# 200
# 53
# here
# 10.3390/en13184843
# https://api.elsevier.com/content/abstract/doi/10.3390/en13184843
# 200
# 54
# here
# 10.3390/su12187546
# https://api.elsevier.com/content/abstract/doi/10.3390/su12187546
# 200
# 55
# here
# 10.12011/1000-6788-2020-0027-34
# https://api.elsevier.com/content/abstract/doi/10.12011/1000-6788-2020-0027-34
# 200
# 56
# here
# 10.3390/su12145836
# https://api.elsevier.com/content/abstract/doi/10.3390/su12145836
# 200
# 57
# here
# 10.3390/su12145679
# https://api.elsevier.com/content/abstract/doi/10.3390/su12145679
# 200
# 58
# here
# 10.1108/JPIF-09-2019-0131
# https://api.elsevier.com/content/abstract/doi/10.1108/JPIF-09-2019-0131
# 200
# 59
# here
# 10.1515/remav-2020-0015
# https://api.elsevier.com/content/abstract/doi/10.1515/remav-2020-0015
# 200
# 60
# here
# 10.3390/LAND9050143
# https://api.elsevier.com/content/abstract/doi/10.3390/LAND9050143
# 200
# 61
# here
# 10.3390/su12072899
# https://api.elsevier.com/content/abstract/doi/10.3390/su12072899
# 200
# 62
# here
# 10.1007/s00521-018-3938-7
# https://api.elsevier.com/content/abstract/doi/10.1007/s00521-018-3938-7
# 200
# 63
# here
# 10.1002/sam.11440
# https://api.elsevier.com/content/abstract/doi/10.1002/sam.11440
# 200
# 64
# here
# 10.1007/s11146-019-09724-w
# https://api.elsevier.com/content/abstract/doi/10.1007/s11146-019-09724-w
# 200
# 65
# here
# 10.4324/9780429430015
# https://api.elsevier.com/content/abstract/doi/10.4324/9780429430015
# 200
# 66
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 67
# 10.3390/ijfs8020036
# https://api.elsevier.com/content/abstract/doi/10.3390/ijfs8020036
# 200
# 68
# here
# 10.1007/978-3-030-33157-3_17
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-030-33157-3_17
# 200
# 69
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 70
# 10.31838/jcr.07.11.88
# https://api.elsevier.com/content/abstract/doi/10.31838/jcr.07.11.88
# 200
# 71
# here
# 10.1109/SSCI44817.2019.9002904
# https://api.elsevier.com/content/abstract/doi/10.1109/SSCI44817.2019.9002904
# 200
# 72
# here
# 10.3390/su11247006
# https://api.elsevier.com/content/abstract/doi/10.3390/su11247006
# 200
# 73
# here
# 10.3390/rs11243047
# https://api.elsevier.com/content/abstract/doi/10.3390/rs11243047
# 200
# 74
# here
# 10.1088/1742-6596/1353/1/012139
# https://api.elsevier.com/content/abstract/doi/10.1088/1742-6596/1353/1/012139
# 200
# 75
# here
# 10.1007/s11042-019-07895-5
# https://api.elsevier.com/content/abstract/doi/10.1007/s11042-019-07895-5
# 200
# 76
# here
# 10.1007/s10994-018-5769-2
# https://api.elsevier.com/content/abstract/doi/10.1007/s10994-018-5769-2
# 200
# 77
# here
# 10.1016/j.trip.2019.100028
# https://api.elsevier.com/content/abstract/doi/10.1016/j.trip.2019.100028
# 200
# 78
# here
# 10.2478/remav-2019-0030
# https://api.elsevier.com/content/abstract/doi/10.2478/remav-2019-0030
# 200
# 79
# here
# 10.3390/su11184896
# https://api.elsevier.com/content/abstract/doi/10.3390/su11184896
# 200
# 80
# here
# 10.1016/j.landusepol.2019.104021
# https://api.elsevier.com/content/abstract/doi/10.1016/j.landusepol.2019.104021
# 200
# 81
# here
# 10.1016/j.physrep.2019.05.002
# https://api.elsevier.com/content/abstract/doi/10.1016/j.physrep.2019.05.002
# 200
# 82
# here
# 10.3390/su11133575
# https://api.elsevier.com/content/abstract/doi/10.3390/su11133575
# 200
# 83
# here
# 10.3390/su11133731
# https://api.elsevier.com/content/abstract/doi/10.3390/su11133731
# 200
# 84
# here
# 10.1108/CI-03-2018-0013
# https://api.elsevier.com/content/abstract/doi/10.1108/CI-03-2018-0013
# 200
# 85
# here
# 10.3390/su11113110
# https://api.elsevier.com/content/abstract/doi/10.3390/su11113110
# 200
# 86
# here
# 10.3390/ijgi8040195
# https://api.elsevier.com/content/abstract/doi/10.3390/ijgi8040195
# 200
# 87
# here
# 10.1108/JERER-08-2018-0035
# https://api.elsevier.com/content/abstract/doi/10.1108/JERER-08-2018-0035
# 200
# 88
# here
# 10.1108/ECAM-02-2018-0045
# https://api.elsevier.com/content/abstract/doi/10.1108/ECAM-02-2018-0045
# 200
# 89
# here
# 10.1109/DSAA.2018.00043
# https://api.elsevier.com/content/abstract/doi/10.1109/DSAA.2018.00043
# 200
# 90
# here
# 10.1017/9781108183062
# https://api.elsevier.com/content/abstract/doi/10.1017/9781108183062
# 200
# 91
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 92
# 10.1111/1540-6229.12293
# https://api.elsevier.com/content/abstract/doi/10.1111/1540-6229.12293
# 200
# 93
# here
# 10.1007/978-981-13-6661-1_13
# https://api.elsevier.com/content/abstract/doi/10.1007/978-981-13-6661-1_13
# 200
# 94
# here
# 10.1007/978-3-319-72434-8_11
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-72434-8_11
# 200
# 95
# here
# 10.1007/978-3-319-92099-3_25
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-92099-3_25
# 200
# 96
# here
# 10.1007/978-3-319-92099-3_17
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-92099-3_17
# 200
# 97
# here
# 10.1007/978-3-319-92099-3_46
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-92099-3_46
# 200
# 98
# here
# 10.1186/s40663-018-0146-y
# https://api.elsevier.com/content/abstract/doi/10.1186/s40663-018-0146-y
# 200
# 99
# here
# 10.1186/s40537-018-0154-3
# https://api.elsevier.com/content/abstract/doi/10.1186/s40537-018-0154-3
# 200
# 100
# here
# 10.1002/9781119241072
# https://api.elsevier.com/content/abstract/doi/10.1002/9781119241072
# 200
# 101
# here
# 10.1007/s12652-017-0508-2
# https://api.elsevier.com/content/abstract/doi/10.1007/s12652-017-0508-2
# 200
# 102
# here
# 10.1108/JPIF-10-2017-0067
# https://api.elsevier.com/content/abstract/doi/10.1108/JPIF-10-2017-0067
# 200
# 103
# here
# 10.1061/(ASCE)UP.1943-5444.0000457
# https://api.elsevier.com/content/abstract/doi/10.1061/(ASCE)UP.1943-5444.0000457
# 200
# 104
# here
# 10.3390/su10093085
# https://api.elsevier.com/content/abstract/doi/10.3390/su10093085
# 200
# 105
# here
# 10.1108/IJHMA-02-2017-0021
# https://api.elsevier.com/content/abstract/doi/10.1108/IJHMA-02-2017-0021
# 200
# 106
# here
# 10.1007/s12517-018-3474-x
# https://api.elsevier.com/content/abstract/doi/10.1007/s12517-018-3474-x
# 200
# 107
# here
# 10.1515/jisys-2016-0100
# https://api.elsevier.com/content/abstract/doi/10.1515/jisys-2016-0100
# 200
# 108
# here
# 10.1007/s40518-018-0098-4
# https://api.elsevier.com/content/abstract/doi/10.1007/s40518-018-0098-4
# 200
# 109
# here
# 10.1016/C2017-0-00713-9
# https://api.elsevier.com/content/abstract/doi/10.1016/C2017-0-00713-9
# 200
# 110
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 111
# 10.1504/IJBIDM.2018.094981
# https://api.elsevier.com/content/abstract/doi/10.1504/IJBIDM.2018.094981
# 200
# 112
# here
# 10.1007/978-3-319-98443-8_49
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-98443-8_49
# 200
# 113
# here
# 10.1002/9781118280249
# https://api.elsevier.com/content/abstract/doi/10.1002/9781118280249
# 200
# 114
# 10.3390/su9112138
# https://api.elsevier.com/content/abstract/doi/10.3390/su9112138
# 200
# 115
# here
# 10.4324/9781315602110
# https://api.elsevier.com/content/abstract/doi/10.4324/9781315602110
# 200
# 116
# here
# 10.3390/en10101587
# https://api.elsevier.com/content/abstract/doi/10.3390/en10101587
# 200
# 117
# here
# 10.1007/s10472-016-9534-6
# https://api.elsevier.com/content/abstract/doi/10.1007/s10472-016-9534-6
# 200
# 118
# here
# 10.1002/9781119073666
# https://api.elsevier.com/content/abstract/doi/10.1002/9781119073666
# 200
# 119
# here
# 10.1007/s40171-017-0159-3
# https://api.elsevier.com/content/abstract/doi/10.1007/s40171-017-0159-3
# 200
# 120
# here
# 10.3846/1648715X.2016.1259190
# https://api.elsevier.com/content/abstract/doi/10.3846/1648715X.2016.1259190
# 200
# 121
# here
# 10.3390/su9060909
# https://api.elsevier.com/content/abstract/doi/10.3390/su9060909
# 200
# 122
# here
# 10.1201/9781315155258
# https://api.elsevier.com/content/abstract/doi/10.1201/9781315155258
# 200
# 123
# here
# 10.1108/ECAM-06-2016-0139
# https://api.elsevier.com/content/abstract/doi/10.1108/ECAM-06-2016-0139
# 200
# 124
# here
# 10.1007/978-3-319-62398-6_14
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-62398-6_14
# 200
# 125
# here
# 10.1016/j.rser.2017.04.018
# https://api.elsevier.com/content/abstract/doi/10.1016/j.rser.2017.04.018
# 200
# 126
# here
# 10.1007/978-3-319-48308-5_19
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-48308-5_19
# 200
# 127
# here
# 10.1109/DSAA.2016.58
# https://api.elsevier.com/content/abstract/doi/10.1109/DSAA.2016.58
# 200
# 128
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 129
# 10.1145/2897165
# https://api.elsevier.com/content/abstract/doi/10.1145/2897165
# 200
# 130
# here
# 10.1109/ICSC.2016.85
# https://api.elsevier.com/content/abstract/doi/10.1109/ICSC.2016.85
# 200
# 131
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 132
# 10.1142/9789813146976_0102
# https://api.elsevier.com/content/abstract/doi/10.1142/9789813146976_0102
# 200
# 133
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 134
# 10.1007/978-3-319-42085-1_14
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-42085-1_14
# 200
# 135
# here
# 10.1007/s10640-014-9874-9
# https://api.elsevier.com/content/abstract/doi/10.1007/s10640-014-9874-9
# 200
# 136
# here
# 10.3390/su8010037
# https://api.elsevier.com/content/abstract/doi/10.3390/su8010037
# 200
# 137
# here
# 10.1016/j.envsoft.2015.07.012
# https://api.elsevier.com/content/abstract/doi/10.1016/j.envsoft.2015.07.012
# 200
# 138
# here
# 10.1080/1331677X.2015.1075139
# https://api.elsevier.com/content/abstract/doi/10.1080/1331677X.2015.1075139
# 200
# 139
# here
# 10.1145/2783258.2783383
# https://api.elsevier.com/content/abstract/doi/10.1145/2783258.2783383
# 200
# 140
# here
# 10.1016/j.habitatint.2015.01.017
# https://api.elsevier.com/content/abstract/doi/10.1016/j.habitatint.2015.01.017
# 200
# 141
# here
# 10.1002/9781119009405
# https://api.elsevier.com/content/abstract/doi/10.1002/9781119009405
# 200
# 142
# here
# 10.1201/b19769
# https://api.elsevier.com/content/abstract/doi/10.1201/b19769
# 200
# 143
# here
# 10.1007/978-3-319-24306-1_55
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-24306-1_55
# 200
# 144
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 145
# 10.17580/gzh.2015.08.21
# https://api.elsevier.com/content/abstract/doi/10.17580/gzh.2015.08.21
# 200
# 146
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 147
# 10.2495/SC140111
# https://api.elsevier.com/content/abstract/doi/10.2495/SC140111
# 200
# 148
# here
# 10.1109/ICDM.2014.18
# https://api.elsevier.com/content/abstract/doi/10.1109/ICDM.2014.18
# 200
# 149
# here
# 10.1080/10919392.2014.866505
# https://api.elsevier.com/content/abstract/doi/10.1080/10919392.2014.866505
# 200
# 150
# here
# 10.4324/9780203109571
# https://api.elsevier.com/content/abstract/doi/10.4324/9780203109571
# 200
# 151
# here
# 10.1007/978-3-642-40495-5_38
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-642-40495-5_38
# 200
# 152
# here
# 10.4018/978-1-4666-4309-3.ch013
# https://api.elsevier.com/content/abstract/doi/10.4018/978-1-4666-4309-3.ch013
# 200
# 153
# here
# 10.1108/IJHMA-08-2012-0039
# https://api.elsevier.com/content/abstract/doi/10.1108/IJHMA-08-2012-0039
# 200
# 154
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 155
# 10.1016/j.landurbplan.2012.09.008
# https://api.elsevier.com/content/abstract/doi/10.1016/j.landurbplan.2012.09.008
# 200
# 156
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 157
# 10.1504/IJECRM.2013.060697
# https://api.elsevier.com/content/abstract/doi/10.1504/IJECRM.2013.060697
# 200
# 158
# here
# 10.1080/10643389.2012.671097
# https://api.elsevier.com/content/abstract/doi/10.1080/10643389.2012.671097
# 200
# 159
# here
# 10.1016/j.dss.2012.10.038
# https://api.elsevier.com/content/abstract/doi/10.1016/j.dss.2012.10.038
# 200
# 160
# here
# 10.1016/C2009-0-24104-3
# https://api.elsevier.com/content/abstract/doi/10.1016/C2009-0-24104-3
# 200
# 161
# here
# 10.1016/j.ijpe.2012.03.036
# https://api.elsevier.com/content/abstract/doi/10.1016/j.ijpe.2012.03.036
# 200
# 162
# here
# 10.1016/j.ins.2011.07.012
# https://api.elsevier.com/content/abstract/doi/10.1016/j.ins.2011.07.012
# 200
# 163
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 164
# 10.1504/IJBIS.2010.035744
# https://api.elsevier.com/content/abstract/doi/10.1504/IJBIS.2010.035744
# 200
# 165
# here
# 10.1007/978-3-642-03958-4_29
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-642-03958-4_29
# 200
# 166
# here
# 10.1109/ACIIDS.2009.46
# https://api.elsevier.com/content/abstract/doi/10.1109/ACIIDS.2009.46
# 200
# 167
# here
# 10.1002/9781444301021.ch9
# https://api.elsevier.com/content/abstract/doi/10.1002/9781444301021.ch9
# 200
# 168
# 10.1017/CBO9781107477971
# https://api.elsevier.com/content/abstract/doi/10.1017/CBO9781107477971
# 200
# 169
# here
# 10.1007/978-3-642-04441-0_70
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-642-04441-0_70
# 200
# 170
# here
# 10.1007/978-3-642-04441-0_73
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-642-04441-0_73
# 200
# 171
# here
# 10.1109/HIS.2008.78
# https://api.elsevier.com/content/abstract/doi/10.1109/HIS.2008.78
# 200
# 172
# here
# 10.3233/978-1-58603-904-2-125
# https://api.elsevier.com/content/abstract/doi/10.3233/978-1-58603-904-2-125
# 200
# 173
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 174
# 10.1017/CBO9780511546013
# https://api.elsevier.com/content/abstract/doi/10.1017/CBO9780511546013
# 200
# 175
# here
# 10.1016/j.ecolecon.2005.10.005
# https://api.elsevier.com/content/abstract/doi/10.1016/j.ecolecon.2005.10.005
# 200
# 176
# here
# 10.1108/02637470610643092
# https://api.elsevier.com/content/abstract/doi/10.1108/02637470610643092
# 200
# 177
# here
# 10.1016/j.jue.2005.10.003
# https://api.elsevier.com/content/abstract/doi/10.1016/j.jue.2005.10.003
# 200
# 178
# here
# 10.1108/02637470510631474
# https://api.elsevier.com/content/abstract/doi/10.1108/02637470510631474
# 200
# 179
# here
# 10.1144/1470-9236/04-072
# https://api.elsevier.com/content/abstract/doi/10.1144/1470-9236/04-072
# 200
# 180
# here
# 10.1016/B978-0-7506-7555-0.X5081-6
# https://api.elsevier.com/content/abstract/doi/10.1016/B978-0-7506-7555-0.X5081-6
# 504
# 181
# 10.1016/S0377-2217(02)00178-9
# https://api.elsevier.com/content/abstract/doi/10.1016/S0377-2217(02)00178-9
# 200
# 182
# here
# 10.1111/1540-6229.00048
# https://api.elsevier.com/content/abstract/doi/10.1111/1540-6229.00048
# 200
# 183
# here

# %%
abstract_list[0]
# Out:
# '© 2021 by the authors. Licensee MDPI, Basel, Switzerland.The accurate estimation of real estate value helps the development of real estate policies that can respond to the complexities and instability of the real estate market. Previously, statistical methods were used to estimate real estate value, but machine learning methods have gained popularity because their predictions are more accurate. In contrast to existing studies that use various machine learning methods to estimate the transactions or list prices of real estate properties without separating the building and land prices, this study estimates land price using a large amount of land-use information obtained from various land-and building-related datasets. The random forest and XGBoost methods were used to estimate 52,900 land prices in Seoul, South Korea, from January 2017 to December 2020. The models were also separately trained for different land uses and different time periods. Overall, the results revealed that XGBoost yields a higher prediction accuracy. Whereas the XGBoost models were more accurate on the 2020 data than on the 2017–2020 data when analyzing residential areas, the random forest models were more accurate on the 2017–2020 data than on the 2020 data. Further analysis will extend the prediction model to consider submarkets determined by price volatility and locality.'

# %%
type(abstract_list[0])
# Out:
# str

# %% [markdown]
# # GUARDAR DADOS RECOLHIDOS E PROCESSADOS

# %%
df_results_list.to_csv('../data/input/'+'search_results.csv',  index=False, encoding = "utf-8")

pd.DataFrame(abstract_list,  columns =['Abstract']).to_csv('../data/input/'+'search_results_abstracts.csv', index=False, encoding = "utf-8")

# %%
# Save the file
#pickle.dump( df_results_list, file = open(path_dados+"ICD2122_TextMining_DataStructures.pickle", "wb"))

# Reload the file
#test_grouped_df_reloaded = pickle.load(open(path_dados+"ICD2122_TextMining_DataStructures.pickle", "rb"))
